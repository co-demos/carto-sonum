# %%
import pandas as pd

# %%
myDict = [
    {
        "A" : "fsdg",
        "B" : [1,2]
    },
    {
        "A" : "fdsgr",
        "B" : [1,2, 3, 4]
    }
]
df = pd.DataFrame(myDict)

# %%
df
# Out:
#        A             B
# 0   fsdg        [1, 2]
# 1  fdsgr  [1, 2, 3, 4]

# %%
df_out = df.to_dict("records")

# %%
list(df_out)
# Out:
# [{'A': 'fsdg', 'B': [1, 2]}, {'A': 'fdsgr', 'B': [1, 2, 3, 4]}]
