# %% [markdown]
# #### CLEAN DATASETS FROM CARTO-SONUM
#
# 10/03/2019 - Julien Paris
#
# for each dataset :
# - read CSV/EXCEL/JSON
# - get unique values from all columns
# - retrieve unique values on specific columns
# - export original data as CSV and XLS files
# - export unique values as a JSON file
#
# cf : https://github.com/co-demos/carto-sonum/tree/master/data

# %%
# -*- encoding: utf-8 -*-
import json
import ast

import pandas as pd
from pandas.io.json import json_normalize
from pandas.api.types import is_string_dtype
import numpy as np

# %%
CSVfiles = [ 

    ### DRJSCS
    {"name" : "export_base_ressources_territoriales_20181227_DRJSCS_HDF", 
     "ext" : "csv",
     "encoding" : "ISO-8859-1",
     "sep" : ";",
     "colsToExclude" : [],
     "colToGetUniques" : [
         u"Enjeu", 
         u"Dispositif", 
         u"Public_cible", 
         u"Statut",
         u"Echelle",
         u"Conditions_acces",
         u"Horaires"
     ],
     "code" : "DRJSCS"
    },
    
    ### MSAP
    {"name" : "MSAP-20180627", 
     "ext" : "csv",
     "encoding" : "ISO-8859-1",
     "sep" : ";",
     "colsToExclude" : [],
     "colToGetUniques" : [
         u"Horaires d'ouverture",
         u"Accessibilité",
         u"Equipements à disposition"
     ],
     "code" : "MSAP"
    },
    
    ### LOIRE ATLANTIQUE
    {"name" : "224400028_lieux-numeriques-en-loire-atlantique", 
     "ext" : "csv",
     "encoding" : "utf-8",
     "sep" : ";",
     "colsToExclude" : [],
     "colToGetUniques" : [
         u"Type de porteur", 
         u"Public",
         u"Tarif(s)"
     ],
     "code" : "Loire-Atlantique"
    },
    
    ### GIRONDE
    {"name" : "listeEPN-NETPUBLIC-Gironde", 
     "ext" : "csv",
     "encoding" : "utf-8",
     "sep" : ",",
     "colsToExclude" : [],
     "colToGetUniques" : [
         u"Label",
         u"Services proposés",
         u"Tarif"
     ],
     "code" : "Gironde"
    },
    
    ### NET PUBLIC 
    {"name" : "Copie de Annuaire EPN Netpublic - decembre 2016", 
     "ext" : "csv",
     "encoding" : "ISO-8859-1",
     "sep" : ";",
     "colsToExclude" : [],
     "colToGetUniques" : [
         u"Statut",
     ],
     "code" : "NetPublic"
    },
    
    ### APTIC
    {"name" : "APTIC - extractCatalog", 
     "ext" : "json",
     "encoding" : "utf-8",
     "sep" : "",
     #"list_fields" : ["services"],
     "colsToExclude" : ["nom_representant", "prenom_representant"],
     "colToGetUniques" : [
         u"Statut",
     ],
     "code" : "APTIC"
    },
]

# %%
class FiletoXLS :
    
    def __init__(self, name, code, ext="csv",sep=";", encoding="utf-8", list_fields=[], cols_to_exclude=[]) : 
        self.filename = name
        self.code = code
        self.ext = ext
        self.file = name + "." + ext
        self.sep = sep
        self.list_fields = list_fields
        self.cols_to_exclude = cols_to_exclude
        self.encoding = encoding
        self.df = None
        self.columnsNames = []
        self.columnsUniques = []

    def toDF(self):
        if self.ext == "csv":
            df = pd.read_csv(self.file, sep=self.sep, encoding=self.encoding)
        elif self.ext == "json":
            with open(self.file) as f:
                data = json.load(f)
            ### normalize columns names
            df = json_normalize(data)
            ### convert lists to strings 
            #df = df.to_string()
        else : 
            df = pd.read_excel(self.file, encoding=self.encoding)
        print df.head(3)
        df = df.dropna(how="all")
        df = df.replace({np.nan:None}) 
        self.df = df[ [c for c in df.columns if c not in self.cols_to_exclude] ]
        return df
    
    def getUniques(self):
        results=[]
        for col in self.df:
            print "---- \ncol : %s" %(col)
            print "\n col[:2] : %s" %(col[:2])

            self.columnsNames.append(col)
            
            ### check serie type
            #is_col_str_type = is_string_dtype(self.df[col])
            #print "\nis_col_str_type : %s" %(is_col_str_type)
            col_dtype_kind = self.df[col].dtype.kind
            print "\n col_dtype_kind : %s" %(col_dtype_kind)

            if col in self.list_fields: 
                self.df[col] = self.df[col].apply(lambda x: ' / '.join(x))
                
            uniques = self.df[col].unique()
            u_dict = {"colname" : col, "uniques" : uniques.tolist() }
            u_dict["u_count"] = len(u_dict["uniques"])
            results.append(u_dict)
        self.columnsUniques = results
        return results
            
    def toXLS(self):
        #writer = pd.ExcelWriter(self.code + '.xlsx')
        #self.df.to_excel(writer, index = False)
        #writer.save()
        filename = "-" + self.code + '.xlsx'
        self.df.to_excel(filename, encoding="utf-8")
    
    def toTSV(self):
        filename = "-" + self.code + '.csv'
        self.df.to_csv(filename, sep='\t', encoding='utf-8')
        
    def toJSON(self):
        filename = "-" + self.code + '.json'
        self.df.to_json(filename, orient="records")

# %%
#CSVlist = [CSVfiles[1]]
CSVlist = CSVfiles

# %%
CSV_dfList = []
for csv in CSVlist:
    list_fields = csv.get("list_fields", [])
    classCSV = FiletoXLS(
        csv["name"],csv["code"],
        ext=csv["ext"],sep=csv["sep"],
        encoding=csv["encoding"], 
        list_fields=list_fields,
        cols_to_exclude=csv["colsToExclude"],
    )
    classCSV.toDF()
    classCSV.getUniques()
    result = { 
        "code" : csv["code"], 
        "df" : classCSV.df, 
        "columnsNames" : classCSV.columnsNames,
        "columnsUniques" : classCSV.columnsUniques,
        "classCSV" : classCSV, 
        "count" : {"rows" : classCSV.df.shape[0],"columns" : classCSV.df.shape[1] },
        "csvInfos" : csv,
        "colUniquesToKeep" : [ c for c in classCSV.columnsUniques if c["colname"] in csv["colToGetUniques"]]
    }
    CSV_dfList.append(result)
# Out:
#     Id          Enjeu                                         Dispositif  \
# 0  617  Accessibilit  Mise  disposition de matriel informatique et...
# 1  616  Accessibilit  Mise  disposition de matriel informatique et...
# 2  590  Accessibilit  Mise  disposition de matriel informatique et...
#
#   Public_cible                              Descriptif  \
# 0  Tout public  Accs  Internet dans la bibliothque.
# 1  Tout public  Accs  Internet dans la bibliothque.
# 2  Tout public  Accs  Internet dans la bibliothque.
#
#          Structure_porteuse              Type_structure  Statut  \
# 0       Bibliotheque Rurale  Bibliothque - Mdiathque  Public
# 1  Mediatheque Henry Murger  Bibliothque - Mdiathque  Public
# 2   Bibliotheque Municipale  Bibliothque - Mdiathque  Public
#
#                            Adresse           Commune      ...         Dpt  \
# 0       PLACE DU GENERAL DE GAULLE            Pavant      ...       Aisne
# 1               PARC DU 8 MAI 1945   Nogent-l'Artaud      ...       Aisne
# 2  Centre culturel Ferdinand Pinal  Charly-sur-Marne      ...       Aisne
#
#             Region Echelle                               Courriel   Telephone  \
# 0  Hauts-de-France  Locale       mathias.bibliotheque@laposte.net  0323707844
# 1  Hauts-de-France  Locale  mediatheque.nogent.lartaud@wanadoo.fr  0323706791
# 2  Hauts-de-France  Locale                 bibliocharly@orange.fr  0323820032
#
#   Accompagnement Conditions_acces Handicaps Horaires Site_internet
# 0            Oui      Accs libre       NaN      NaN           NaN
# 1            Oui      Accs libre       NaN      NaN           NaN
# 2            Oui      Accs libre       NaN      NaN           NaN
#
# [3 rows x 21 columns]
# ----
# col : Id
#
#  col[:2] : Id
#
#  col_dtype_kind : i
# ----
# col : Enjeu
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Dispositif
#
#  col[:2] : Di
#
#  col_dtype_kind : O
# ----
# col : Public_cible
#
#  col[:2] : Pu
#
#  col_dtype_kind : O
# ----
# col : Descriptif
#
#  col[:2] : De
#
#  col_dtype_kind : O
# ----
# col : Structure_porteuse
#
#  col[:2] : St
#
#  col_dtype_kind : O
# ----
# col : Type_structure
#
#  col[:2] : Ty
#
#  col_dtype_kind : O
# ----
# col : Statut
#
#  col[:2] : St
#
#  col_dtype_kind : O
# ----
# col : Adresse
#
#  col[:2] : Ad
#
#  col_dtype_kind : O
# ----
# col : Commune
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : CP
#
#  col[:2] : CP
#
#  col_dtype_kind : i
# ----
# col : Dpt
#
#  col[:2] : Dp
#
#  col_dtype_kind : O
# ----
# col : Region
#
#  col[:2] : Re
#
#  col_dtype_kind : O
# ----
# col : Echelle
#
#  col[:2] : Ec
#
#  col_dtype_kind : O
# ----
# col : Courriel
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Telephone
#
#  col[:2] : Te
#
#  col_dtype_kind : O
# ----
# col : Accompagnement
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Conditions_acces
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Handicaps
#
#  col[:2] : Ha
#
#  col_dtype_kind : O
# ----
# col : Horaires
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Site_internet
#
#  col[:2] : Si
#
#  col_dtype_kind : O
#                                                  Nom  \
# 0  Maison du Conseil départemental de Crèvecoeur-...
# 1                                           Mercoeur
# 2                                               AACA
#
#                                         Présentation Photo  \
# 0  La Maison du Conseil départemental de Crèvecoe...   Oui
# 1  LES MAISONS DE SERVICES AU PUBLIC DU DÉPARTEME...   Oui
# 2  LAACA est un centre social, un lieu ressource...   Oui
#
#                                 Horaires d'ouverture Services itinérants  \
# 0  LUNDI : 14H-17H MARDI : 9H30-12H30 ET 14H-17H ...                 Non
# 1  Lundi :  8h30 à 12h30 et de 13h30 à 17h30 Merc...                 Non
# 2  Lundi de 10h à 12h et de 14h à 17h Mardi de 9h...                 Non
#
#                 Adresse Complément d'adresse  Code Postal               Ville  \
# 0  24 avenue du Château                  NaN        60360  Crèvecur-le-Grand
# 1              Le Bourg                  NaN        19430             Mercur
# 2      Allée du Château        parc Rochette        73220          Aiguebelle
#
#                        Email de contact             ...               \
# 0                mcg-crevecoeur@oise.fr             ...
# 1  maisondepartementmercoeur@correze.fr             ...
# 2          al.chataux@aacaiguebelle.com             ...
#
#                 Autres équipements  \
# 0                 SALLE DE RÉUNION
# 1  Salle de réunion - Bibliothèque
# 2                              NaN
#
#                                Dans les mêmes locaux  \
# 0  Espace Public Numérique|Relai Assistantes Mate...
# 1                                       Bibliothèque
# 2  Centre social|Relai Assistantes Maternelles (RAM)
#
#   Autres services dans les locaux Année d'ouverture de la maison  \
# 0                             NaN                     05/07/2008
# 1                             NaN                     27/04/2007
# 2                             NaN                            NaN
#
#   Année de labellisation de la maison  \
# 0                          05/07/2008
# 1                          18/04/2017
# 2                          01/06/2011
#
#   Structure porteuse de la Maison de services au public  \
# 0                                   DEPARTEMENT OISE
# 1                          Département de la Corrèze
# 2  AACA : Association d'Animation du Canton d'Aig...
#
#   Appartenance à un réseau territorial  \
# 0                                  NaN
# 1                                  NaN
# 2                               ADRETS
#
#   Connexion avec d'autres Maisons de services au public  \
# 0                                                NaN
# 1  Beaulieu, Beynat, Eygurande, Saint Privat, Sornac
# 2                                                NaN
#
#                      Autres labels Informations complémentaires
# 0  MAISON DU CONSEIL DEPARTEMENTAL                          NaN
# 1                              NaN                          NaN
# 2                 Point relais CAF                          NaN
#
# [3 rows x 77 columns]
# ----
# col : Nom
#
#  col[:2] : No
#
#  col_dtype_kind : O
# ----
# col : Présentation
#
#  col[:2] : Pr
#
#  col_dtype_kind : O
# ----
# col : Photo
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Horaires d'ouverture
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Services itinérants
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Adresse
#
#  col[:2] : Ad
#
#  col_dtype_kind : O
# ----
# col : Complément d'adresse
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Code Postal
#
#  col[:2] : Co
#
#  col_dtype_kind : i
# ----
# col : Ville
#
#  col[:2] : Vi
#
#  col_dtype_kind : O
# ----
# col : Email de contact
#
#  col[:2] : Em
#
#  col_dtype_kind : O
# ----
# col : Site internet
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : Téléphone
#
#  col[:2] : Té
#
#  col_dtype_kind : O
# ----
# col : Parking à proximité
#
#  col[:2] : Pa
#
#  col_dtype_kind : O
# ----
# col : Accès transports en commun
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Plan d'accès
#
#  col[:2] : Pl
#
#  col_dtype_kind : O
# ----
# col : Accessibilité
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Lien Facebook
#
#  col[:2] : Li
#
#  col_dtype_kind : O
# ----
# col : Lien Twitter
#
#  col[:2] : Li
#
#  col_dtype_kind : O
# ----
# col : Lien Google+
#
#  col[:2] : Li
#
#  col_dtype_kind : O
# ----
# col : Date de création de la fiche
#
#  col[:2] : Da
#
#  col_dtype_kind : O
# ----
# col : Date de la dernière modification de la fiche
#
#  col[:2] : Da
#
#  col_dtype_kind : O
# ----
# col : Pôle emploi
#
#  col[:2] : Pô
#
#  col_dtype_kind : O
# ----
# col : CPAM
#
#  col[:2] : CP
#
#  col_dtype_kind : O
# ----
# col : CNAV
#
#  col[:2] : CN
#
#  col_dtype_kind : O
# ----
# col : GRDF
#
#  col[:2] : GR
#
#  col_dtype_kind : O
# ----
# col : La Poste
#
#  col[:2] : La
#
#  col_dtype_kind : O
# ----
# col : MSA
#
#  col[:2] : MS
#
#  col_dtype_kind : O
# ----
# col : CAF
#
#  col[:2] : CA
#
#  col_dtype_kind : O
# ----
# col : Agence départementale d'information sur le logement (ADIL)
#
#  col[:2] : Ag
#
#  col_dtype_kind : O
# ----
# col : Agence locale de lénergie (ALE)
#
#  col[:2] : Ag
#
#  col_dtype_kind : O
# ----
# col : Banque de France
#
#  col[:2] : Ba
#
#  col_dtype_kind : O
# ----
# col : Cap Emploi
#
#  col[:2] : Ca
#
#  col_dtype_kind : O
# ----
# col : Centre communal d'action sociale (CCAS)
#
#  col[:2] : Ce
#
#  col_dtype_kind : O
# ----
# col : Centre intercommunal daction sociale (CIAS)
#
#  col[:2] : Ce
#
#  col_dtype_kind : O
# ----
# col : Centre local d'information et de coordination (CLIC)
#
#  col[:2] : Ce
#
#  col_dtype_kind : O
# ----
# col : Centre social
#
#  col[:2] : Ce
#
#  col_dtype_kind : O
# ----
# col : Chambre d'agriculture
#
#  col[:2] : Ch
#
#  col_dtype_kind : O
# ----
# col : Chambre de commerce et d'industrie (CCI)
#
#  col[:2] : Ch
#
#  col_dtype_kind : O
# ----
# col : Chambre de métiers et de l'artisanat (CMA)
#
#  col[:2] : Ch
#
#  col_dtype_kind : O
# ----
# col : Conseil départemental
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Conseil départemental de laccès au droit (CDAD)
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Croix-Rouge
#
#  col[:2] : Cr
#
#  col_dtype_kind : O
# ----
# col : Défenseur des droits
#
#  col[:2] : Dé
#
#  col_dtype_kind : O
# ----
# col : EDF
#
#  col[:2] : ED
#
#  col_dtype_kind : O
# ----
# col : Fédération nationale des accidentés du travail et des handicapés (FNATH)
#
#  col[:2] : Fé
#
#  col_dtype_kind : O
# ----
# col : Greta (formation continue pour les adultes)
#
#  col[:2] : Gr
#
#  col_dtype_kind : O
# ----
# col : Maison de l'emploi
#
#  col[:2] : Ma
#
#  col_dtype_kind : O
# ----
# col : Maison départementale des personnes handicapées (MDPH)
#
#  col[:2] : Ma
#
#  col_dtype_kind : O
# ----
# col : Médecine du travail
#
#  col[:2] : Mé
#
#  col_dtype_kind : O
# ----
# col : Mission locale
#
#  col[:2] : Mi
#
#  col_dtype_kind : O
# ----
# col : Plan local pour l'insertion et lemploi (PLIE)
#
#  col[:2] : Pl
#
#  col_dtype_kind : O
# ----
# col : Point d'accès au droit
#
#  col[:2] : Po
#
#  col_dtype_kind : O
# ----
# col : Point d'appui à la vie associative
#
#  col[:2] : Po
#
#  col_dtype_kind : O
# ----
# col : Point Info Famille
#
#  col[:2] : Po
#
#  col_dtype_kind : O
# ----
# col : Point Info Jeunesse
#
#  col[:2] : Po
#
#  col_dtype_kind : O
# ----
# col : Point Protection Maternelle Infantile
#
#  col[:2] : Po
#
#  col_dtype_kind : O
# ----
# col : Préfecture
#
#  col[:2] : Pr
#
#  col_dtype_kind : O
# ----
# col : Protection, Amélioration, Conservation, Transformation de l'habitat (PACT)
#
#  col[:2] : Pr
#
#  col_dtype_kind : O
# ----
# col : Régime social des indépendants (RSI)
#
#  col[:2] : Ré
#
#  col_dtype_kind : O
# ----
# col : Réseau d'Ecoute, d'Appui et d'Accompagnement des Parents (REAAP)
#
#  col[:2] : Ré
#
#  col_dtype_kind : O
# ----
# col : Trésor Public
#
#  col[:2] : Tr
#
#  col_dtype_kind : O
# ----
# col : Union de Recouvrement des Cotisations de Sécurité Sociale et d'Allocations Familiales (URSSAF)
#
#  col[:2] : Un
#
#  col_dtype_kind : O
# ----
# col : Union départementale des associations familiales (UDAF)
#
#  col[:2] : Un
#
#  col_dtype_kind : O
# ----
# col : Autre
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : Autres partenaires et services
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : Planning des permanences
#
#  col[:2] : Pl
#
#  col_dtype_kind : O
# ----
# col : Equipements à disposition
#
#  col[:2] : Eq
#
#  col_dtype_kind : O
# ----
# col : Autres équipements
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : Dans les mêmes locaux
#
#  col[:2] : Da
#
#  col_dtype_kind : O
# ----
# col : Autres services dans les locaux
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : Année d'ouverture de la maison
#
#  col[:2] : An
#
#  col_dtype_kind : O
# ----
# col : Année de labellisation de la maison
#
#  col[:2] : An
#
#  col_dtype_kind : O
# ----
# col : Structure porteuse de la Maison de services au public
#
#  col[:2] : St
#
#  col_dtype_kind : O
# ----
# col : Appartenance à un réseau territorial
#
#  col[:2] : Ap
#
#  col_dtype_kind : O
# ----
# col : Connexion avec d'autres Maisons de services au public
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Autres labels
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : Informations complémentaires
#
#  col[:2] : In
#
#  col_dtype_kind : O
#                                Nom du lieu                   Nom du porteur  \
# 0              Bibliothèque A Livre Ouvert      Bibliothèque A Livre Ouvert
# 1                          CCAS Le Croisic                  CCAS Le Croisic
# 2  Caisse d'Allocations Familiales Clisson  Caisse d'Allocations Familiales
#
#                       Adresse mail             Type de porteur  \
# 0  bibliotheque@sainte-pazanne.com  Bibliothèque / Médiathèque
# 1                ccas@lecroisic.fr                 Institution
# 2                              NaN                 Institution
#
#   Détail du type de porteur                    Adresse  Code postal  \
# 0                       NaN     32 avenue de la source        44680
# 1                       NaN  3 rue de la Duchesse Anne        44490
# 2                       NaN  2 rue du Docteur Doussain        44190
#
#           Commune  Code INSEE Numéro de téléphone  \
# 0  Sainte-Pazanne       44186          0240026913
# 1      Le Croisic       44049          0228567900
# 2         Clisson       44043          0240540212
#
#                 ...                \
# 0               ...
# 1               ...
# 2               ...
#
#                                    Équipements Ordinateur(s) libellé  \
# 0  Ordinateur(s),Imprimante(s),Connexion Wi-Fi         Ordinateur(s)
# 1  Ordinateur(s),Imprimante(s),Connexion Wi-Fi         Ordinateur(s)
# 2                                 Borne(s) CAF                   NaN
#
#   Tablette(s) libellé Scanner(s) libellé Imprimante(s) libellé  \
# 0                 NaN                NaN         Imprimante(s)
# 1                 NaN                NaN         Imprimante(s)
# 2                 NaN                NaN                   NaN
#
#   Borne(s) CAF libellé Connexion Wi-Fi libellé Formation libellé  \
# 0                  NaN         Connexion Wi-Fi         Formation
# 1                  NaN         Connexion Wi-Fi               NaN
# 2         Borne(s) CAF                     NaN               NaN
#
#   Accompagnement individuel individuel libellé Fourniture d'équipement libellé
# 0                    Accompagnement individuel                             NaN
# 1                    Accompagnement individuel                             NaN
# 2                    Accompagnement individuel                             NaN
#
# [3 rows x 54 columns]
# ----
# col : Nom du lieu
#
#  col[:2] : No
#
#  col_dtype_kind : O
# ----
# col : Nom du porteur
#
#  col[:2] : No
#
#  col_dtype_kind : O
# ----
# col : Adresse mail
#
#  col[:2] : Ad
#
#  col_dtype_kind : O
# ----
# col : Type de porteur
#
#  col[:2] : Ty
#
#  col_dtype_kind : O
# ----
# col : Détail du type de porteur
#
#  col[:2] : Dé
#
#  col_dtype_kind : O
# ----
# col : Adresse
#
#  col[:2] : Ad
#
#  col_dtype_kind : O
# ----
# col : Code postal
#
#  col[:2] : Co
#
#  col_dtype_kind : i
# ----
# col : Commune
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Code INSEE
#
#  col[:2] : Co
#
#  col_dtype_kind : i
# ----
# col : Numéro de téléphone
#
#  col[:2] : Nu
#
#  col_dtype_kind : O
# ----
# col : Site web
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : Descriptif
#  col[:2] : De
#
#  col_dtype_kind : O
# ----
# col : Logo
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : Photo
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Public
#
#  col[:2] : Pu
#
#  col_dtype_kind : O
# ----
# col : Accès
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Restrictions d'usage
#
#  col[:2] : Re
#
#  col_dtype_kind : O
# ----
# col : Tarif(s)
#
#  col[:2] : Ta
#
#  col_dtype_kind : O
# ----
# col : Horaires du lundi
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Horaires du mardi
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Horaires du mercredi
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Horaires du jeudi
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Horaires du vendredi
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Horaires du samedi
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Horaires du dimanche
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Complément sur les horaires
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Ordinateur(s)
#
#  col[:2] : Or
#
#  col_dtype_kind : i
# ----
# col : Tablette(s)
#
#  col[:2] : Ta
#
#  col_dtype_kind : i
# ----
# col : Scanner(s)
#
#  col[:2] : Sc
#
#  col_dtype_kind : i
# ----
# col : Imprimante(s)
#
#  col[:2] : Im
#
#  col_dtype_kind : i
# ----
# col : Borne(s) CAF
#
#  col[:2] : Bo
#
#  col_dtype_kind : i
# ----
# col : Connexion Wi-Fi
#
#  col[:2] : Co
#
#  col_dtype_kind : i
# ----
# col : Complément sur les équipements
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Formation
#
#  col[:2] : Fo
#
#  col_dtype_kind : i
# ----
# col : Accompagnement individuel
#
#  col[:2] : Ac
#
#  col_dtype_kind : i
# ----
# col : Fourniture d'équipement
#
#  col[:2] : Fo
#
#  col_dtype_kind : i
# ----
# col : Complément sur les services
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Compte InfoLocale
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Localisation
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : Clé
#
#  col[:2] : Cl
#
#  col_dtype_kind : O
# ----
# col : Date de saisie
#
#  col[:2] : Da
#
#  col_dtype_kind : O
# ----
# col : Date d'enregistrement
#
#  col[:2] : Da
#
#  col_dtype_kind : O
# ----
# col : Date de modification
#
#  col[:2] : Da
#
#  col_dtype_kind : O
# ----
# col : Services
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Équipements
#
#  col[:2] : Éq
#
#  col_dtype_kind : O
# ----
# col : Ordinateur(s) libellé
#
#  col[:2] : Or
#
#  col_dtype_kind : O
# ----
# col : Tablette(s) libellé
#
#  col[:2] : Ta
#
#  col_dtype_kind : O
# ----
# col : Scanner(s) libellé
#
#  col[:2] : Sc
#
#  col_dtype_kind : O
# ----
# col : Imprimante(s) libellé
#
#  col[:2] : Im
#
#  col_dtype_kind : O
# ----
# col : Borne(s) CAF libellé
#
#  col[:2] : Bo
#
#  col_dtype_kind : O
# ----
# col : Connexion Wi-Fi libellé
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Formation libellé
#
#  col[:2] : Fo
#
#  col_dtype_kind : O
# ----
# col : Accompagnement individuel individuel libellé
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Fourniture d'équipement libellé
#
#  col[:2] : Fo
#
#  col_dtype_kind : O
#                 Identifiant Date de dernière modification  \
# 0                       NaN                           NaN
# 1  4f3401aade77fe55ff00063c                    14/02/2012
# 2                        4B                           NaN
#
#                                    Nom       Label Label Net-Public  \
# 0  Centre Socio culturel la Passerelle        PAPI              NaN
# 1      Médiathèque François Mitterrand  Cyber-base                1
# 2                                  BIJ        PAPI         Jeunesse
#
#    Demande de labellisation Net-Public             Site Web  \
# 0                                  NaN                  NaN
# 1                                  0.0                  NaN
# 2                                  NaN  www.mairie-ambes.fr
#
#                           N° et libellé de voie  Code Insee commune  \
# 0                   2 Place du Maréchal Leclerc                 NaN
# 1                 5 avenue du docteur Couaillac             33004.0
# 2  Centre Georges Brassens Place du 11 Novembre                 4.0
#
#    Code postal   ...    Services proposés.1 Villes Internet Accueil de jeunes  \
# 0      33440.0   ...                    NaN             NaN               NaN
# 1      33810.0   ...                    NaN             NaN               NaN
# 2      33810.0   ...                    NaN             NaN               NaN
#
#   Accueil de seniors  Organisation d'évènements  \
# 0                NaN                        NaN
# 1                NaN                        NaN
# 2                NaN                        NaN
#
#    Centre d'Animation des Portes Ferrées Personne à contacter.1 Image  \
# 0                                    NaN                    NaN   NaN
# 1                                    NaN                    NaN   NaN
# 2                                    NaN                    NaN   NaN
#
#   N° et libellé de voie.6  Mission
# 0                     NaN      NaN
# 1                     NaN      NaN
# 2                     NaN      NaN
#
# [3 rows x 105 columns]
# ----
# col : Identifiant
#
#  col[:2] : Id
#
#  col_dtype_kind : O
# ----
# col : Date de dernière modification
#
#  col[:2] : Da
#
#  col_dtype_kind : O
# ----
# col : Nom
#
#  col[:2] : No
#
#  col_dtype_kind : O
# ----
# col : Label
#
#  col[:2] : La
#
#  col_dtype_kind : O
# ----
# col : Label Net-Public
#
#  col[:2] : La
#
#  col_dtype_kind : O
# ----
# col : Demande de labellisation Net-Public
#
#  col[:2] : De
#
#  col_dtype_kind : O
# ----
# col : Site Web
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : N° et libellé de voie
#
#  col[:2] : N°
#
#  col_dtype_kind : O
# ----
# col : Code Insee commune
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Code postal
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Localité
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : Téléphone
#
#  col[:2] : Té
#
#  col_dtype_kind : O
# ----
# col : Email
#
#  col[:2] : Em
#
#  col_dtype_kind : O
# ----
# col : Latitude
#
#  col[:2] : La
#
#  col_dtype_kind : O
# ----
# col : Longitude
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : Précision
#
#  col[:2] : Pr
#
#  col_dtype_kind : O
# ----
# col : Personne à contacter
#
#  col[:2] : Pe
#
#  col_dtype_kind : O
# ----
# col : Services proposés
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Nombre d'animateurs
#
#  col[:2] : No
#
#  col_dtype_kind : O
# ----
# col : Numéro DUI
#
#  col[:2] : Nu
#
#  col_dtype_kind : O
# ----
# col : Photo
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Statut
#
#  col[:2] : St
#
#  col_dtype_kind : O
# ----
# col : Autre label
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : N° et libellé de voie.1
#
#  col[:2] : N°
#
#  col_dtype_kind : O
# ----
# col : Horaires d'ouverture
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Entrée - Accès [Accessibilité]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Équipement
#
#  col[:2] : Éq
#
#  col_dtype_kind : O
# ----
# col : Entrée - Ouverture de porte [Accessibilité]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Entrée - Obstacle à la porte d'entrée [Accessibilité]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Circulation - Circulation dans les allées [Accessibilité]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Circulation - Accès en fauteuil dans tout le lieu [Accessibilité]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Circulation - Ascenseurs (dimensions) [Accessibilité]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Services et équipements - Sanitaires [Accessibilité]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Services et équipements - Personnel formé à l'accueil des personnes en situation de handicap [Accessibilité]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Services et équipements - Personnel initié à la langue des signes [Accessibilité]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Extérieur - Place de parking réservée [Accessibilité]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Extérieur - Places GIC/GIR à proximité [Accessibilité]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Extérieur - Transports accessibles à proximité [Accessibilité]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Tarif
#
#  col[:2] : Ta
#
#  col_dtype_kind : O
# ----
# col : Photo.1
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Photo.2
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Photo.3
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : N° et libellé de voie.2
#
#  col[:2] : N°
#
#  col_dtype_kind : O
# ----
# col : Code Insee commune.1
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Code postal.1
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Localité.1
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : N° et libellé de voie.3
#
#  col[:2] : N°
#
#  col_dtype_kind : O
# ----
# col : Circulation - Signalétique adaptée [Accessibilité]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Services et équipements - Hauteur adaptée des comptoirs / guichets [Accessibilité]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : services et équipements - Personnel formé à l'accueil des personnes en situation de handicap [Accessibilité]
#
#  col[:2] : se
#
#  col_dtype_kind : O
# ----
# col : Services et équipements - Place réservée au PMR [Accessibilité]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Extérieur - Enseigne suffisamment lisible et visible [Accessibilité]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Spécificité territoriale
#
#  col[:2] : Sp
#
#  col_dtype_kind : O
# ----
# col : Circulation - Ascenseurs (adaptations) [Accessibilité]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Photo.4
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Photo.5
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Photo.6
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Photo.7
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Photo.8
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Flux d'actualité
#
#  col[:2] : Fl
#
#  col_dtype_kind : O
# ----
# col : Courriel
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Horaires initiations et ateliers
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Entrée - Accès contrôlé [Accessibilité]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Circulation - Escaliers [Accessibilité]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Services et équipements - Visites adaptées aux personnes ayant une déficience [Accessibilité]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Entrée - Largeur de porte en cm [Accessibilité]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Circulation - Guidage [Accessibilité]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Blog
#
#  col[:2] : Bl
#
#  col_dtype_kind : O
# ----
# col : Extérieur - Trottoirs (Obstacles) [Accessibilité]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Entrée - En cas de présence d'une marche, préciser sa hauteur en cm [Accessibilité]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Rue, Voie, Chemin
#
#  col[:2] : Ru
#
#  col_dtype_kind : O
# ----
# col : Rue, Voie, Chemin.1
#
#  col[:2] : Ru
#
#  col_dtype_kind : O
# ----
# col : Fédération Nationale de Sport Numérique
#
#  col[:2] : Fé
#
#  col_dtype_kind : O
# ----
# col : Ateliers
#
#  col[:2] : At
#
#  col_dtype_kind : O
# ----
# col : Espace Public Numérique (EPN des Yvelines)
#
#  col[:2] : Es
#
#  col_dtype_kind : O
# ----
# col : Commentaire
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Intitulé
#
#  col[:2] : In
#
#  col_dtype_kind : O
# ----
# col : Autre Site Web
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : Texte long
#
#  col[:2] : Te
#
#  col_dtype_kind : O
# ----
# col : N° et libellé de voie.4
#
#  col[:2] : N°
#
#  col_dtype_kind : O
# ----
# col : N° et libellé de voie.5
#
#  col[:2] : N°
#
#  col_dtype_kind : O
# ----
# col : Code Insee commune.2
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Code postal.2
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Localité.2
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : Site Web2
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : Vidéo
#
#  col[:2] : Vi
#
#  col_dtype_kind : O
# ----
# col : Circulation - Plan du lieu [Accessibilité]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : NETPUBLIC
#
#  col[:2] : NE
#
#  col_dtype_kind : O
# ----
# col : Site Web de Formation ORDIDACTIC60
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : Vidéo.1
#
#  col[:2] : Vi
#
#  col_dtype_kind : O
# ----
# col : Visio-accueil Pôle-Emploi
#
#  col[:2] : Vi
#
#  col_dtype_kind : O
# ----
# col : Le blog de la médiathèque
#
#  col[:2] : Le
#
#  col_dtype_kind : O
# ----
# col : Fax
#
#  col[:2] : Fa
#
#  col_dtype_kind : O
# ----
# col : Ce flux présente les actualités locales de l'Espace Informatique Cyber-base®
#
#  col[:2] : Ce
#
#  col_dtype_kind : O
# ----
# col : Ce flux affiche les programmes des ateliers qui sont planifiés à l'Espace Informatique Cyber-base®
#
#  col[:2] : Ce
#
#  col_dtype_kind : O
# ----
# col : Services proposés.1
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Villes Internet
#
#  col[:2] : Vi
#
#  col_dtype_kind : O
# ----
# col : Accueil de jeunes
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Accueil de seniors
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Organisation d'évènements
#
#  col[:2] : Or
#
#  col_dtype_kind : O
# ----
# col : Centre d'Animation des Portes Ferrées
#
#  col[:2] : Ce
#
#  col_dtype_kind : O
# ----
# col : Personne à contacter.1
#
#  col[:2] : Pe
#
#  col_dtype_kind : O
# ----
# col : Image
#
#  col[:2] : Im
#
#  col_dtype_kind : O
# ----
# col : N° et libellé de voie.6
#
#  col[:2] : N°
#
#  col_dtype_kind : O
# ----
# col : Mission
#
#  col[:2] : Mi
#
#  col_dtype_kind : O
# /Users/jpy/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (33,58,59,63,66,68,69,70,71,72,75,77,78,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,99,101,102,103,104,105,106,108,110,111,113,114,115,116,117,119,120,121,122,123,124,125,126,127,128,129,130,131) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#                 Identifiant Date de dernire modification  \
# 0  54ec6c76de77fe0314ee3a1d                    24/02/2015
# 1  4f340209de77fe55ff000e7b                    14/02/2012
# 2  4f340209de77fe55ff000e7a                    14/02/2012
#
#                                Nom                 Statut  \
# 0              Association Lalouma  Structure associative
# 1  Espace Cyber-base EPM de Lavaur                    NaN
# 2                         APER-CTL                    NaN
#
#                  Labels territoriaux  Label NetPublic  \
# 0        PassNumrique (Rhne Alpes)                1
# 1                                NaN                1
# 2  Cyber-centre (Nord-Pas-de-Calais)                1
#
#    Mise en oeuvre du dispositif "2000 Emplois d'Avenir en EPN"  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
#
#    Demande de labellisation NetPublic  \
# 0                                 0.0
# 1                                 0.0
# 2                                 0.0
#
#                                             Site Web  \
# 0                             http://www.lalouma.org
# 1  http://www.cyber-base.org/cyberbase/afficheInf...
# 2                                                NaN
#
#          N¡ et libell de voie   ...    Accueil de seniors  \
# 0  78 monte de la Grande Cte   ...                   NaN
# 1           275 rue de Cocagne   ...                   NaN
# 2            Ruelle de Prseau   ...                   NaN
#
#   Organisation d'vnements  Image Centre d'Animation des Portes Ferres  \
# 0                       NaN    NaN                                   NaN
# 1                       NaN    NaN                                   NaN
# 2                       NaN    NaN                                   NaN
#
#   Tlphone direct REPAIR CAFE  EPN ORDI2.0 Coworking  Mission
# 0              NaN         NaN  NaN     NaN       NaN      NaN
# 1              NaN         NaN  NaN     NaN       NaN      NaN
# 2              NaN         NaN  NaN     NaN       NaN      NaN
#
# [3 rows x 132 columns]
# ----
# col : Identifiant
#
#  col[:2] : Id
#
#  col_dtype_kind : O
# ----
# col : Date de dernire modification
#
#  col[:2] : Da
#
#  col_dtype_kind : O
# ----
# col : Nom
#
#  col[:2] : No
#
#  col_dtype_kind : O
# ----
# col : Statut
#
#  col[:2] : St
#
#  col_dtype_kind : O
# ----
# col : Labels territoriaux
#
#  col[:2] : La
#
#  col_dtype_kind : O
# ----
# col : Label NetPublic
#
#  col[:2] : La
#
#  col_dtype_kind : i
# ----
# col : Mise en oeuvre du dispositif "2000 Emplois d'Avenir en EPN"
#
#  col[:2] : Mi
#
#  col_dtype_kind : O
# ----
# col : Demande de labellisation NetPublic
#
#  col[:2] : De
#
#  col_dtype_kind : O
# ----
# col : Site Web
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : N¡ et libell de voie
#
#  col[:2] : N¡
#
#  col_dtype_kind : O
# ----
# col : N¡ et libell de voie.1
#
#  col[:2] : N¡
#
#  col_dtype_kind : O
# ----
# col : Code Insee commune
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Code postal
#
#  col[:2] : Co
#
#  col_dtype_kind : i
# ----
# col : Localit
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : Tlphone
#
#  col[:2] : T
#
#  col_dtype_kind : O
# ----
# col : Email
#
#  col[:2] : Em
#
#  col_dtype_kind : O
# ----
# col : Horaires d'ouverture
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Latitude
#
#  col[:2] : La
#
#  col_dtype_kind : O
# ----
# col : Longitude
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : Prcision
#
#  col[:2] : Pr
#
#  col_dtype_kind : O
# ----
# col : Personne  contacter
#
#  col[:2] : Pe
#
#  col_dtype_kind : O
# ----
# col : Services proposs
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : quipement
#
#  col[:2] : q
#
#  col_dtype_kind : O
# ----
# col : Tarif
#
#  col[:2] : Ta
#
#  col_dtype_kind : O
# ----
# col : Nombre d'animateurs
#
#  col[:2] : No
#
#  col_dtype_kind : O
# ----
# col : Entre - Accs [Accessibilit]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Entre - En cas de prsence d'une marche, prciser sa hauteur en cm [Accessibilit]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Entre - Ouverture de porte [Accessibilit]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Entre - Largeur de porte en cm [Accessibilit]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Entre - Obstacle  la porte d'entre [Accessibilit]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Entre - Accs contrl [Accessibilit]
#
#  col[:2] : En
#
#  col_dtype_kind : O
# ----
# col : Circulation - Circulation dans les alles [Accessibilit]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Circulation - Accs en fauteuil dans tout le lieu [Accessibilit]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Texte court
#
#  col[:2] : Te
#
#  col_dtype_kind : O
# ----
# col : Extrieur - Places GIC/GIR  proximit [Accessibilit]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Extrieur - Transports accessibles  proximit [Accessibilit]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Labels nationaux
#
#  col[:2] : La
#
#  col_dtype_kind : O
# ----
# col : Numro Agence du Numrique
#
#  col[:2] : Nu
#
#  col_dtype_kind : O
# ----
# col : Autre label
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : Extrieur - Enseigne suffisamment lisible et visible [Accessibilit]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Nombre de mdiateurs numriques et de techniciens
#
#  col[:2] : No
#
#  col_dtype_kind : O
# ----
# col : Courriel
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Photo
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Agrment service civique numrique
#
#  col[:2] : Ag
#
#  col_dtype_kind : O
# ----
# col : Circulation - Signaltique adapte [Accessibilit]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Services et quipements - Hauteur adapte des comptoirs / guichets [Accessibilit]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Services et quipements - Personnel form  l'accueil des personnes en situation de handicap [Accessibilit]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Services et quipements - Personnel initi  la langue des signes [Accessibilit]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Circulation - Guidage [Accessibilit]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Services et quipements - Sanitaires [Accessibilit]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Spcificit territoriale
#
#  col[:2] : Sp
#
#  col_dtype_kind : O
# ----
# col : Services et quipements - Place rserve au PMR [Accessibilit]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : Extrieur - Place de parking rserve [Accessibilit]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Extrieur - Trottoirs (Obstacles) [Accessibilit]
#
#  col[:2] : Ex
#
#  col_dtype_kind : O
# ----
# col : Circulation - Ascenseurs (dimensions) [Accessibilit]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Circulation - Plan du lieu [Accessibilit]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Circulation - Ascenseurs (adaptations) [Accessibilit]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Circulation - Escaliers [Accessibilit]
#
#  col[:2] : Ci
#
#  col_dtype_kind : O
# ----
# col : Actualits
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Rseau social
#
#  col[:2] : R
#
#  col_dtype_kind : O
# ----
# col : N¡ et libell de voie.2
#
#  col[:2] : N¡
#
#  col_dtype_kind : O
# ----
# col : Services et quipements - Visites adaptes aux personnes ayant une dficience [Accessibilit]
#
#  col[:2] : Se
#
#  col_dtype_kind : O
# ----
# col : services et quipements - Personnel form  l'accueil des personnes en situation de handicap [Accessibilit]
#
#  col[:2] : se
#
#  col_dtype_kind : O
# ----
# col : N¡ et libell de voie.3
#
#  col[:2] : N¡
#
#  col_dtype_kind : O
# ----
# col : Code Insee commune.1
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Code postal.1
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Localit.1
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : Photo.1
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Page Facebook
#
#  col[:2] : Pa
#
#  col_dtype_kind : O
# ----
# col : Nombre de services civiques accueillis
#
#  col[:2] : No
#
#  col_dtype_kind : O
# ----
# col : Page facebook
#
#  col[:2] : Pa
#
#  col_dtype_kind : O
# ----
# col : Page Twitter
#
#  col[:2] : Pa
#
#  col_dtype_kind : O
# ----
# col : Villes Internet
#
#  col[:2] : Vi
#
#  col_dtype_kind : O
# ----
# col : Dbit
#
#  col[:2] : D
#
#  col_dtype_kind : O
# ----
# col : Photo.2
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Site Web1
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : Demande de labellisation NetPublic.1
#
#  col[:2] : De
#
#  col_dtype_kind : O
# ----
# col : NETPUBLIC
#
#  col[:2] : NE
#
#  col_dtype_kind : O
# ----
# col : Horaires initiations et ateliers
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Texte long
#
#  col[:2] : Te
#
#  col_dtype_kind : O
# ----
# col : Rue, Voie, Chemin
#
#  col[:2] : Ru
#
#  col_dtype_kind : O
# ----
# col : Rue, Voie, Chemin.1
#
#  col[:2] : Ru
#
#  col_dtype_kind : O
# ----
# col : Fdration Nationale de Sport Numrique
#
#  col[:2] : F
#
#  col_dtype_kind : O
# ----
# col : Ateliers
#
#  col[:2] : At
#
#  col_dtype_kind : O
# ----
# col : Photo.3
#
#  col[:2] : Ph
#
#  col_dtype_kind : O
# ----
# col : Espace Public Numrique (EPN des Yvelines)
#
#  col[:2] : Es
#
#  col_dtype_kind : O
# ----
# col : ComCom
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Accueil ComCom
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Tlphone (bis)
#  col[:2] : T
#
#  col_dtype_kind : O
# ----
# col : Fax
#
#  col[:2] : Fa
#
#  col_dtype_kind : O
# ----
# col : Intitul
#
#  col[:2] : In
#
#  col_dtype_kind : O
# ----
# col : Commentaire
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Autre Site Web
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : Personne  contacter.1
#
#  col[:2] : Pe
#
#  col_dtype_kind : O
# ----
# col : Offre de services spcifiques
#
#  col[:2] : Of
#
#  col_dtype_kind : O
# ----
# col : N¡ et libell de voie.4
#
#  col[:2] : N¡
#
#  col_dtype_kind : O
# ----
# col : N¡ et libell de voie.5
#
#  col[:2] : N¡
#
#  col_dtype_kind : O
# ----
# col : Code Insee commune.2
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Code postal.2
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Localit.2
#
#  col[:2] : Lo
#
#  col_dtype_kind : O
# ----
# col : N¡ et libell de voie.6
#
#  col[:2] : N¡
#
#  col_dtype_kind : O
# ----
# col : Autre site web
#
#  col[:2] : Au
#
#  col_dtype_kind : O
# ----
# col : Site Web2
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : Vido
#
#  col[:2] : Vi
#
#  col_dtype_kind : O
# ----
# col : Site Web LCN
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : Association
#
#  col[:2] : As
#
#  col_dtype_kind : O
# ----
# col : Site Web.1
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : Animateur
#
#  col[:2] : An
#
#  col_dtype_kind : O
# ----
# col : adresse email
#
#  col[:2] : ad
#
#  col_dtype_kind : O
# ----
# col : formateurs numriques
#
#  col[:2] : fo
#
#  col_dtype_kind : O
# ----
# col : email
#
#  col[:2] : em
#
#  col_dtype_kind : O
# ----
# col : Instagram
#
#  col[:2] : In
#
#  col_dtype_kind : O
# ----
# col : Label NetPublic.1
#
#  col[:2] : La
#
#  col_dtype_kind : O
# ----
# col : Site Web de Formation ORDIDACTIC60
#
#  col[:2] : Si
#
#  col_dtype_kind : O
# ----
# col : Vido.1
#
#  col[:2] : Vi
#
#  col_dtype_kind : O
# ----
# col : Visio-accueil Ple-Emploi
#
#  col[:2] : Vi
#
#  col_dtype_kind : O
# ----
# col : Le blog de la mdiathque
#
#  col[:2] : Le
#
#  col_dtype_kind : O
# ----
# col : Horaires d't
#
#  col[:2] : Ho
#
#  col_dtype_kind : O
# ----
# col : Adresse email
#
#  col[:2] : Ad
#
#  col_dtype_kind : O
# ----
# col : Blog du Ple Multimdia
#
#  col[:2] : Bl
#
#  col_dtype_kind : O
# ----
# col : Netvibes Ressources en ligne
#
#  col[:2] : Ne
#
#  col_dtype_kind : O
# ----
# col : Accueil de jeunes
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Accueil de seniors
#
#  col[:2] : Ac
#
#  col_dtype_kind : O
# ----
# col : Organisation d'vnements
#
#  col[:2] : Or
#
#  col_dtype_kind : O
# ----
# col : Image
#
#  col[:2] : Im
#
#  col_dtype_kind : O
# ----
# col : Centre d'Animation des Portes Ferres
#
#  col[:2] : Ce
#
#  col_dtype_kind : O
# ----
# col : Tlphone direct
#
#  col[:2] : T
#
#  col_dtype_kind : O
# ----
# col : REPAIR CAFE
#
#  col[:2] : RE
#
#  col_dtype_kind : O
# ----
# col : EPN
#
#  col[:2] : EP
#
#  col_dtype_kind : O
# ----
# col : ORDI2.0
#
#  col[:2] : OR
#
#  col_dtype_kind : O
# ----
# col : Coworking
#
#  col[:2] : Co
#
#  col_dtype_kind : O
# ----
# col : Mission
#
#  col[:2] : Mi
#
#  col_dtype_kind : O
#                 adresse code_postal horaires        lat       lng  \
# 0  3 rue Anatole France       05400           44.535761  5.826327
# 1     3, rue de la gare       21230           47.130672  4.491322
# 2    Rue Gustave Gresse       26400           44.715386  5.054418
#
#                                     nom_structure  \
# 0      Centre de Ressources des Hauts Pays Alpins
# 1  CENTRE SOCIAL ET SOCIOCULTUREL DU PAYS D'ARNAY
# 2                   MJC Centre Social Nini Chaize
#
#                                             services        telephone   ville
# 0  Organiser sa recherche d'emploi / Découverte e...  04 92 57 24 02   Veynes
# 1  Internet : fonctionnement et outils de navigat...   03.80.90.17.55
# 2  Internet : déposer une annonce sur Le Bon Coin...   04.75.25.14.20
# ----
# col : adresse
#
#  col[:2] : ad
#
#  col_dtype_kind : O
# ----
# col : code_postal
#
#  col[:2] : co
#
#  col_dtype_kind : O
# ----
# col : horaires
#
#  col[:2] : ho
#
#  col_dtype_kind : O
# ----
# col : lat
#
#  col[:2] : la
#
#  col_dtype_kind : f
# ----
# col : lng
#
#  col[:2] : ln
#
#  col_dtype_kind : f
# ----
# col : nom_structure
#
#  col[:2] : no
#
#  col_dtype_kind : O
# ----
# col : services
#
#  col[:2] : se
#
#  col_dtype_kind : O
# ----
# col : telephone
#
#  col[:2] : te
#
#  col_dtype_kind : O
# ----
# col : ville
#
#  col[:2] : vi
#
#  col_dtype_kind : O

# %%
for csv in CSV_dfList:
    print "- code : %s" %(csv["code"])
    print "- count : %s" %(csv["count"])
    print "- columnsNames : " 
    #print csv["columnsNames"]
    for c in csv["columnsNames"] : 
        print c
    print
    col = csv["columnsUniques"]
    for c in col : 
        if c in csv["colUniquesToKeep"]: 
            print "- colname : %s" %(c["colname"])
            print "- uniques[0:3] : %s..." %(c["uniques"][0:3])
            print "- u_count : %s" %(c["u_count"])
            print "- "*5
    print "=== "*10
# Out:
# - code : DRJSCS
# - count : {'rows': 1404, 'columns': 21}
# - columnsNames :
# Id
# Enjeu
# Dispositif
# Public_cible
# Descriptif
# Structure_porteuse
# Type_structure
# Statut
# Adresse
# Commune
# CP
# Dpt
# Region
# Echelle
# Courriel
# Telephone
# Accompagnement
# Conditions_acces
# Handicaps
# Horaires
# Site_internet
#
# - colname : Enjeu
# - uniques[0:3] : [u'Accessibilit\x8e', u'Formation et Accompagnement', u'Simplification']...
# - u_count : 3
# - - - - -
# - colname : Dispositif
# - uniques[0:3] : [u"Mise \x88 disposition de mat\x8eriel informatique et d'une connexion internet en acc\x8fs libre", u"Point d'accueil num\x8erique", u'Accompagnement aux d\x8emarches administratives - Accueil Caf\x8e itin\x8erant']...
# - u_count : 145
# - - - - -
# - colname : Public_cible
# - uniques[0:3] : [u'Tout public', u"Demandeurs d'emploi", u'S\x8eniors \x8eloign\x8es du num\x8eriques']...
# - u_count : 88
# - - - - -
# - colname : Statut
# - uniques[0:3] : [u'Public', u'Priv\x8e', u'Public / Priv\x8e']...
# - u_count : 6
# - - - - -
# - colname : Echelle
# - uniques[0:3] : [u'Locale', u'R\x8egionale', u'D\x8epartementale']...
# - u_count : 5
# - - - - -
# - colname : Conditions_acces
# - uniques[0:3] : [u'Acc\x8fs libre', u'Acc\x8fs libre avec accompagnement personnalis\x8e sur demande', None]...
# - u_count : 49
# - - - - -
# - colname : Horaires
# - uniques[0:3] : [None, u'Du lundi au jeudi : 08:30-16:30 / Vendredi : 09:00-12:00', u'Du lundi au vendredi : 08:45-12:00']...
# - u_count : 402
# - - - - -
# === === === === === === === === === ===
# - code : MSAP
# - count : {'rows': 1277, 'columns': 77}
# - columnsNames :
# Nom
# Présentation
# Photo
# Horaires d'ouverture
# Services itinérants
# Adresse
# Complément d'adresse
# Code Postal
# Ville
# Email de contact
# Site internet
# Téléphone
# Parking à proximité
# Accès transports en commun
# Plan d'accès
# Accessibilité
# Lien Facebook
# Lien Twitter
# Lien Google+
# Date de création de la fiche
# Date de la dernière modification de la fiche
# Pôle emploi
# CPAM
# CNAV
# GRDF
# La Poste
# MSA
# CAF
# Agence départementale d'information sur le logement (ADIL)
# Agence locale de lénergie (ALE)
# Banque de France
# Cap Emploi
# Centre communal d'action sociale (CCAS)
# Centre intercommunal daction sociale (CIAS)
# Centre local d'information et de coordination (CLIC)
# Centre social
# Chambre d'agriculture
# Chambre de commerce et d'industrie (CCI)
# Chambre de métiers et de l'artisanat (CMA)
# Conseil départemental
# Conseil départemental de laccès au droit (CDAD)
# Croix-Rouge
# Défenseur des droits
# EDF
# Fédération nationale des accidentés du travail et des handicapés (FNATH)
# Greta (formation continue pour les adultes)
# Maison de l'emploi
# Maison départementale des personnes handicapées (MDPH)
# Médecine du travail
# Mission locale
# Plan local pour l'insertion et lemploi (PLIE)
# Point d'accès au droit
# Point d'appui à la vie associative
# Point Info Famille
# Point Info Jeunesse
# Point Protection Maternelle Infantile
# Préfecture
# Protection, Amélioration, Conservation, Transformation de l'habitat (PACT)
# Régime social des indépendants (RSI)
# Réseau d'Ecoute, d'Appui et d'Accompagnement des Parents (REAAP)
# Trésor Public
# Union de Recouvrement des Cotisations de Sécurité Sociale et d'Allocations Familiales (URSSAF)
# Union départementale des associations familiales (UDAF)
# Autre
# Autres partenaires et services
# Planning des permanences
# Equipements à disposition
# Autres équipements
# Dans les mêmes locaux
# Autres services dans les locaux
# Année d'ouverture de la maison
# Année de labellisation de la maison
# Structure porteuse de la Maison de services au public
# Appartenance à un réseau territorial
# Connexion avec d'autres Maisons de services au public
# Autres labels
# Informations complémentaires
#
# - colname : Horaires d'ouverture
# - uniques[0:3] : [u'LUNDI : 14H-17H MARDI : 9H30-12H30 ET 14H-17H MERCREDI : 9H30-12H30 ET 14H-17H JEUDI : 9H30-12H30 ET 14H-17H VENDREDI : 9H30-12H30 ET 14H-17H', u'Lundi :\xa0 8h30 \xe0 12h30 et de 13h30 \xe0 17h30 Mercredi : 8h30 \xe0 12h30 et de 13h30 \xe0 17h30 Vendredi : 8h30 \xe0 12h30 et de 13h30 \xe0 17h30', u'Lundi de 10h \xe0 12h et de 14h \xe0 17h Mardi de 9h \xe0 12h Mercredi de 9h \xe0 12h et de 14h \xe0 17h Jeudi de 9h \xe0 12h et de 14h \xe0 17h Vendredi de 9h \xe0 12h']...
# - u_count : 1232
# - - - - -
# - colname : Accessibilité
# - uniques[0:3] : [u'Handicap moteur', u'Handicap mental, Handicap moteur', u'Handicap auditif, Handicap mental, Handicap moteur, Handicap visuel']...
# - u_count : 15
# - - - - -
# - colname : Equipements à disposition
# - uniques[0:3] : [u'Acc\xe8s Internet|Espace de confidentialit\xe9|Fax|Imprimante|Photocopieuse|Scanner|T\xe9l\xe9phone|Wifi', u'Acc\xe8s Internet|Fax|Imprimante|Photocopieuse|Scanner|T\xe9l\xe9phone', u'Acc\xe8s Internet|Espace de confidentialit\xe9|Fax|Imprimante|Photocopieuse|Scanner|T\xe9l\xe9phone']...
# - u_count : 82
# - - - - -
# === === === === === === === === === ===
# - code : Loire-Atlantique
# - count : {'rows': 219, 'columns': 54}
# - columnsNames :
# Nom du lieu
# Nom du porteur
# Adresse mail
# Type de porteur
# Détail du type de porteur
# Adresse
# Code postal
# Commune
# Code INSEE
# Numéro de téléphone
# Site web
# Descriptif
# Logo
# Photo
# Public
# Accès
# Restrictions d'usage
# Tarif(s)
# Horaires du lundi
# Horaires du mardi
# Horaires du mercredi
# Horaires du jeudi
# Horaires du vendredi
# Horaires du samedi
# Horaires du dimanche
# Complément sur les horaires
# Ordinateur(s)
# Tablette(s)
# Scanner(s)
# Imprimante(s)
# Borne(s) CAF
# Connexion Wi-Fi
# Complément sur les équipements
# Formation
# Accompagnement individuel
# Fourniture d'équipement
# Complément sur les services
# Compte InfoLocale
# Localisation
# Clé
# Date de saisie
# Date d'enregistrement
# Date de modification
# Services
# Équipements
# Ordinateur(s) libellé
# Tablette(s) libellé
# Scanner(s) libellé
# Imprimante(s) libellé
# Borne(s) CAF libellé
# Connexion Wi-Fi libellé
# Formation libellé
# Accompagnement individuel individuel libellé
# Fourniture d'équipement libellé
#
# - colname : Type de porteur
# - uniques[0:3] : [u'Biblioth\xe8que / M\xe9diath\xe8que', u'Institution', u'Association']...
# - u_count : 4
# - - - - -
# - colname : Public
# - uniques[0:3] : [u'tout public', u'11-17 ans', u'travailleurs ind\xe9pendants']...
# - u_count : 13
# - - - - -
# - colname : Tarif(s)
# - uniques[0:3] : [u"gratuit : \xe9tudiants et demandeurs d'emploi \u25aa Consultations r\xe9guli\xe8res + acc\xe8s wifi : adh\xe9sion 8\u20ac/an \u25aa Ateliers : 5\u20ac/atelier ou 30\u20ac le forfait annuel (CC Coeur  Pays de Retz) - 10\u20ac/atelier (hors CC Coeur Pays de Retz)", u'gratuit', u'gratuit ou prix tr\xe8s r\xe9duit']...
# - u_count : 57
# - - - - -
# === === === === === === === === === ===
# - code : Gironde
# - count : {'rows': 336, 'columns': 105}
# - columnsNames :
# Identifiant
# Date de dernière modification
# Nom
# Label
# Label Net-Public
# Demande de labellisation Net-Public
# Site Web
# N° et libellé de voie
# Code Insee commune
# Code postal
# Localité
# Téléphone
# Email
# Latitude
# Longitude
# Précision
# Personne à contacter
# Services proposés
# Nombre d'animateurs
# Numéro DUI
# Photo
# Statut
# Autre label
# N° et libellé de voie.1
# Horaires d'ouverture
# Entrée - Accès [Accessibilité]
# Équipement
# Entrée - Ouverture de porte [Accessibilité]
# Entrée - Obstacle à la porte d'entrée [Accessibilité]
# Circulation - Circulation dans les allées [Accessibilité]
# Circulation - Accès en fauteuil dans tout le lieu [Accessibilité]
# Circulation - Ascenseurs (dimensions) [Accessibilité]
# Services et équipements - Sanitaires [Accessibilité]
# Services et équipements - Personnel formé à l'accueil des personnes en situation de handicap [Accessibilité]
# Services et équipements - Personnel initié à la langue des signes [Accessibilité]
# Extérieur - Place de parking réservée [Accessibilité]
# Extérieur - Places GIC/GIR à proximité [Accessibilité]
# Extérieur - Transports accessibles à proximité [Accessibilité]
# Tarif
# Photo.1
# Photo.2
# Photo.3
# N° et libellé de voie.2
# Code Insee commune.1
# Code postal.1
# Localité.1
# N° et libellé de voie.3
# Circulation - Signalétique adaptée [Accessibilité]
# Services et équipements - Hauteur adaptée des comptoirs / guichets [Accessibilité]
# services et équipements - Personnel formé à l'accueil des personnes en situation de handicap [Accessibilité]
# Services et équipements - Place réservée au PMR [Accessibilité]
# Extérieur - Enseigne suffisamment lisible et visible [Accessibilité]
# Spécificité territoriale
# Circulation - Ascenseurs (adaptations) [Accessibilité]
# Photo.4
# Photo.5
# Photo.6
# Photo.7
# Photo.8
# Flux d'actualité
# Courriel
# Horaires initiations et ateliers
# Entrée - Accès contrôlé [Accessibilité]
# Circulation - Escaliers [Accessibilité]
# Services et équipements - Visites adaptées aux personnes ayant une déficience [Accessibilité]
# Entrée - Largeur de porte en cm [Accessibilité]
# Circulation - Guidage [Accessibilité]
# Blog
# Extérieur - Trottoirs (Obstacles) [Accessibilité]
# Entrée - En cas de présence d'une marche, préciser sa hauteur en cm [Accessibilité]
# Rue, Voie, Chemin
# Rue, Voie, Chemin.1
# Fédération Nationale de Sport Numérique
# Ateliers
# Espace Public Numérique (EPN des Yvelines)
# Commentaire
# Intitulé
# Autre Site Web
# Texte long
# N° et libellé de voie.4
# N° et libellé de voie.5
# Code Insee commune.2
# Code postal.2
# Localité.2
# Site Web2
# Vidéo
# Circulation - Plan du lieu [Accessibilité]
# NETPUBLIC
# Site Web de Formation ORDIDACTIC60
# Vidéo.1
# Visio-accueil Pôle-Emploi
# Le blog de la médiathèque
# Fax
# Ce flux présente les actualités locales de l'Espace Informatique Cyber-base®
# Ce flux affiche les programmes des ateliers qui sont planifiés à l'Espace Informatique Cyber-base®
# Services proposés.1
# Villes Internet
# Accueil de jeunes
# Accueil de seniors
# Organisation d'évènements
# Centre d'Animation des Portes Ferrées
# Personne à contacter.1
# Image
# N° et libellé de voie.6
# Mission
#
# - colname : Label
# - uniques[0:3] : [u'PAPI', u'Cyber-base', None]...
# - u_count : 11
# - - - - -
# - colname : Services proposés
# - uniques[0:3] : [None, u"Accompagnement individuel\nInitiation Internet et multim\xe9dia\nPratiques culturelles, cr\xe9ation artistique \nAccompagnement scolaire, activit\xe9s \xe9ducatives\nRecherche d'emploi sur Internet\nD\xe9marches administratives", u"Accompagnement individuel\nInitiation Internet et multim\xe9dia\nPerfectionnement, accompagnement de projets\nPratiques culturelles, cr\xe9ation artistique \nAccompagnement scolaire, activit\xe9s \xe9ducatives\nRecherche d'emploi sur Internet\nD\xe9marches administratives"]...
# - u_count : 28
# - - - - -
# - colname : Tarif
# - uniques[0:3] : [None, u'Gratuit', u'Payant']...
# - u_count : 9
# - - - - -
# === === === === === === === === === ===
# - code : NetPublic
# - count : {'rows': 4847, 'columns': 132}
# - columnsNames :
# Identifiant
# Date de dernire modification
# Nom
# Statut
# Labels territoriaux
# Label NetPublic
# Mise en oeuvre du dispositif "2000 Emplois d'Avenir en EPN"
# Demande de labellisation NetPublic
# Site Web
# N¡ et libell de voie
# N¡ et libell de voie.1
# Code Insee commune
# Code postal
# Localit
# Tlphone
# Email
# Horaires d'ouverture
# Latitude
# Longitude
# Prcision
# Personne  contacter
# Services proposs
# quipement
# Tarif
# Nombre d'animateurs
# Entre - Accs [Accessibilit]
# Entre - En cas de prsence d'une marche, prciser sa hauteur en cm [Accessibilit]
# Entre - Ouverture de porte [Accessibilit]
# Entre - Largeur de porte en cm [Accessibilit]
# Entre - Obstacle  la porte d'entre [Accessibilit]
# Entre - Accs contrl [Accessibilit]
# Circulation - Circulation dans les alles [Accessibilit]
# Circulation - Accs en fauteuil dans tout le lieu [Accessibilit]
# Texte court
# Extrieur - Places GIC/GIR  proximit [Accessibilit]
# Extrieur - Transports accessibles  proximit [Accessibilit]
# Labels nationaux
# Numro Agence du Numrique
# Autre label
# Extrieur - Enseigne suffisamment lisible et visible [Accessibilit]
# Nombre de mdiateurs numriques et de techniciens
# Courriel
# Photo
# Agrment service civique numrique
# Circulation - Signaltique adapte [Accessibilit]
# Services et quipements - Hauteur adapte des comptoirs / guichets [Accessibilit]
# Services et quipements - Personnel form  l'accueil des personnes en situation de handicap [Accessibilit]
# Services et quipements - Personnel initi  la langue des signes [Accessibilit]
# Circulation - Guidage [Accessibilit]
# Services et quipements - Sanitaires [Accessibilit]
# Spcificit territoriale
# Services et quipements - Place rserve au PMR [Accessibilit]
# Extrieur - Place de parking rserve [Accessibilit]
# Extrieur - Trottoirs (Obstacles) [Accessibilit]
# Circulation - Ascenseurs (dimensions) [Accessibilit]
# Circulation - Plan du lieu [Accessibilit]
# Circulation - Ascenseurs (adaptations) [Accessibilit]
# Circulation - Escaliers [Accessibilit]
# Actualits
# Rseau social
# N¡ et libell de voie.2
# Services et quipements - Visites adaptes aux personnes ayant une dficience [Accessibilit]
# services et quipements - Personnel form  l'accueil des personnes en situation de handicap [Accessibilit]
# N¡ et libell de voie.3
# Code Insee commune.1
# Code postal.1
# Localit.1
# Photo.1
# Page Facebook
# Nombre de services civiques accueillis
# Page facebook
# Page Twitter
# Villes Internet
# Dbit
# Photo.2
# Site Web1
# Demande de labellisation NetPublic.1
# NETPUBLIC
# Horaires initiations et ateliers
# Texte long
# Rue, Voie, Chemin
# Rue, Voie, Chemin.1
# Fdration Nationale de Sport Numrique
# Ateliers
# Photo.3
# Espace Public Numrique (EPN des Yvelines)
# ComCom
# Accueil ComCom
# Tlphone (bis)
# Fax
# Intitul
# Commentaire
# Autre Site Web
# Personne  contacter.1
# Offre de services spcifiques
# N¡ et libell de voie.4
# N¡ et libell de voie.5
# Code Insee commune.2
# Code postal.2
# Localit.2
# N¡ et libell de voie.6
# Autre site web
# Site Web2
# Vido
# Site Web LCN
# Association
# Site Web.1
# Animateur
# adresse email
# formateurs numriques
# email
# Instagram
# Label NetPublic.1
# Site Web de Formation ORDIDACTIC60
# Vido.1
# Visio-accueil Ple-Emploi
# Le blog de la mdiathque
# Horaires d't
# Adresse email
# Blog du Ple Multimdia
# Netvibes Ressources en ligne
# Accueil de jeunes
# Accueil de seniors
# Organisation d'vnements
# Image
# Centre d'Animation des Portes Ferres
# Tlphone direct
# REPAIR CAFE
# EPN
# ORDI2.0
# Coworking
# Mission
#
# - colname : Statut
# - uniques[0:3] : [u'Structure associative', None, u'Collectivit\x8e publique']...
# - u_count : 6
# - - - - -
# === === === === === === === === === ===
# - code : APTIC
# - count : {'rows': 136, 'columns': 9}
# - columnsNames :
# adresse
# code_postal
# horaires
# lat
# lng
# nom_structure
# services
# telephone
# ville
#
# === === === === === === === === === ===

# %%
#CSV_dfList[0]["df"].head(3)

# %%
for csvClass in CSV_dfList:
    csvClass["classCSV"].toXLS()
    csvClass["classCSV"].toTSV()
    csvClass["classCSV"].toJSON()

    ### dump json only for uniques
    with open( "-" + csvClass["code"] + '-infos.json', 'w') as fp:
        dict_to_dump = {
            k:v for k,v in csvClass.iteritems() if k in [
                "code", "columnsNames", "count", "csvInfos", "colUniquesToKeep"
            ]
        }
        json.dump(dict_to_dump, fp)
# Out:
# /Users/jpy/anaconda2/lib/python2.7/site-packages/xlsxwriter/worksheet.py:830: UserWarning: Ignoring URL 'http://mediatheque.mairie-verrieres-91.fr/
# Accs%20%20l'espace%20multimdia%20libre%20sur%20rservation%20sur%20place%20ou%20par%20tlphone
#
# Mardi%20:%2016h00%20-%2019h00
# Mercredi%20:%2010h00%20-%2012h30%20%20//%2014h00%20-%2018h00
# Jeudi%20:%20Fermeture
# Vendredi%20:%20Fermeture
# Samedi%20:%2010h00%20-%2012h30%20//%2014h00%20-%2018h00' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /Users/jpy/anaconda2/lib/python2.7/site-packages/xlsxwriter/worksheet.py:830: UserWarning: Ignoring URL 'http://mobile18.fr/du-materiel-innovant-9
#
# Les%20animateurs%20du%20Mobile%20se%20dplacent%20dans%20un%20vhicule%20facilement%20identifiable%20!%20Mais%20attention,%20contrairement%20%20certaines%20ides%20reues,%20ce%20ne%20sont%20pas%20les%20participants%20qui%20montent%20dans%20le%20vhicule%20mais%20bien%20le%20matriel%20qui%20en%20sort%20pour%20tre%20install%20dans%20une%20salle%20mise%20%20disposition%20par%20le%20lieux%20d'accueil%20(communes,%20communaut%20de%20communes,%20associations,%20cole...)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
