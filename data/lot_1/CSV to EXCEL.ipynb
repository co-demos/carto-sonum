# %%
# -*- encoding: utf-8 -*-

import pandas as pd
import numpy as np

# %%
class CSVtoXLS :
    
    def __init__(self, name, code, ext="csv",sep=";", encoding="utf-8") : 
        self.filename = name
        self.code = code
        self.ext = ext
        self.file = name + "." + ext
        self.sep = sep
        self.encoding = encoding
        self.df = None
        self.columnsNames = []
        self.columnsUniques = []

    def toDF(self):
        if self.ext == "csv":
            df = pd.read_csv(self.file, sep=self.sep, encoding=self.encoding)
        else : 
            df = pd.read_excel(self.file, encoding=self.encoding)
        df = df.dropna(how="all")
        df = df.replace({np.nan:None}) 
        self.df = df
        return df
    
    def getUniques(self):
        results=[]
        for col in self.df:
            self.columnsNames.append(col)
            uniques = self.df[col].unique()
            u_dict = {"colname" : col, "uniques" : uniques.tolist() }
            u_dict["u_count"] = len(u_dict["uniques"])
            results.append(u_dict)
        self.columnsUniques = results
        return results
            
    def toXLS(self):
        #writer = pd.ExcelWriter(self.code + '.xlsx')
        #self.df.to_excel(writer, index = False)
        #writer.save()
        filename = "-" + self.code + '.xlsx'
        self.df.to_excel(filename, encoding="utf-8")
    
    def toTSV(self):
        filename = "-" + self.code + '.csv'
        self.df.to_csv(filename, sep='\t', encoding='utf-8')

# %%
CSVfiles = [
    {"name" : "export_base_ressources_territoriales_20181227_DRJSCS_HDF", 
     "ext" : "csv",
     "encoding" : "ISO-8859-1",
     "sep" : ";",
     "colToGetUniques" : [
         u"Enjeu", 
         u"Dispositif", 
         u"Public_cible", 
         u"Statut",
         u"Echelle",
         u"Conditions_acces",
         u"Horaires"
     ],
     "code" : "DRJSCS"
    },
    
    {"name" : "MSAP-20180627", 
     "ext" : "csv",
     "encoding" : "ISO-8859-1",
     "sep" : ";",
     "colToGetUniques" : [
         u"Horaires d'ouverture",
         u"Accessibilité",
         u"Equipements à disposition"
     ],
     "code" : "MSAP"
    },
    
    {"name" : "224400028_lieux-numeriques-en-loire-atlantique", 
     "ext" : "csv",
     "encoding" : "utf-8",
     "sep" : ";",
     "colToGetUniques" : [
         u"Type de porteur", 
         u"Public",
         u"Tarif(s)"
     ],
     "code" : "Loire-Atlantique"
    },
    
    {"name" : "listeEPN-NETPUBLIC-Gironde", 
     "ext" : "csv",
     "encoding" : "utf-8",
     "sep" : ",",
     "colToGetUniques" : [
         u"Label",
         u"Services proposés",
         u"Tarif"
     ],
     "code" : "Gironde"
    },
]

# %%
#CSVlist = [CSVfiles[0]]
CSVlist = CSVfiles

# %%
CSV_dfList = []
for csv in CSVlist:
    classCSV = CSVtoXLS(csv["name"],csv["code"],ext=csv["ext"],sep=csv["sep"],encoding=csv["encoding"] )
    classCSV.toDF()
    classCSV.getUniques()
    result = { 
        "code" : csv["code"], 
        "df" : classCSV.df, 
        "columnsNames" : classCSV.columnsNames,
        "columnsUniques" : classCSV.columnsUniques,
        "classCSV" : classCSV, 
        "csvInfos" : csv,
        "colUniquesToKeep" : [ c["colname"] for c in classCSV.columnsUniques if c["colname"] in csv["colToGetUniques"]]
    }
    CSV_dfList.append(result)

# %%
for csv in CSV_dfList:
    print "columnsNames : " 
    for c in csv["columnsNames"] : 
        print c
    print
    col = csv["columnsUniques"]
    for c in col : 
        print "colname : %s" %(c["colname"])
        print "uniques[0:3] : %s..." %(c["uniques"][0:3])
        print "u_count : %s" %(c["u_count"])
        print "- "*5
    print "=== "*10
# Out:
# columnsNames :
# Id
# Enjeu
# Dispositif
# Public_cible
# Descriptif
# Structure_porteuse
# Type_structure
# Statut
# Adresse
# Commune
# CP
# Dpt
# Region
# Echelle
# Courriel
# Telephone
# Accompagnement
# Conditions_acces
# Handicaps
# Horaires
# Site_internet
#
# colname : Id
# uniques[0:3] : [617, 616, 590]...
# u_count : 1404
# - - - - -
# colname : Enjeu
# uniques[0:3] : [u'Accessibilit\x8e', u'Formation et Accompagnement', u'Simplification']...
# u_count : 3
# - - - - -
# colname : Dispositif
# uniques[0:3] : [u"Mise \x88 disposition de mat\x8eriel informatique et d'une connexion internet en acc\x8fs libre", u"Point d'accueil num\x8erique", u'Accompagnement aux d\x8emarches administratives - Accueil Caf\x8e itin\x8erant']...
# u_count : 145
# - - - - -
# colname : Public_cible
# uniques[0:3] : [u'Tout public', u"Demandeurs d'emploi", u'S\x8eniors \x8eloign\x8es du num\x8eriques']...
# u_count : 88
# - - - - -
# colname : Descriptif
# uniques[0:3] : [u'Acc\x8fs \x88 Internet dans la biblioth\x8fque.', u"P\x99le Emploi propose dans ses locaux un espace disposant d'\x8equipement informatique accessible librement par les usagers pour r\x8ealiser leurs d\x8emarches P\x99le Emploi en ligne.", u"Acc\x8fs libre \x88 un ordinateur avec acc\x8fs aux sites internet d\x8edi\x8es aux t\x8el\x8eproc\x8edures. Il est possible d'\x90tre accompagn\x8e."]...
# u_count : 349
# - - - - -
# colname : Structure_porteuse
# uniques[0:3] : [u'Bibliotheque Rurale', u'Mediatheque Henry Murger', u'Bibliotheque Municipale']...
# u_count : 818
# - - - - -
# colname : Type_structure
# uniques[0:3] : [u'Biblioth\x8fque - M\x8ediath\x8fque', u'P\x99le Emploi', u'Administration - Collectivit\x8e territoriale']...
# u_count : 9
# - - - - -
# colname : Statut
# uniques[0:3] : [u'Public', u'Priv\x8e', u'Public / Priv\x8e']...
# u_count : 6
# - - - - -
# colname : Adresse
# uniques[0:3] : [u'PLACE DU GENERAL DE GAULLE', u'PARC DU 8 MAI 1945', u'Centre culturel Ferdinand Pinal']...
# u_count : 950
# - - - - -
# colname : Commune
# uniques[0:3] : [u'Pavant', u"Nogent-l'Artaud", u'Charly-sur-Marne']...
# u_count : 785
# - - - - -
# colname : CP
# uniques[0:3] : [2310, 2400, 60950]...
# u_count : 440
# - - - - -
# colname : Dpt
# uniques[0:3] : [u'Aisne', u'Oise', u'Somme']...
# u_count : 6
# - - - - -
# colname : Region
# uniques[0:3] : [u'Hauts-de-France']...
# u_count : 1
# - - - - -
# colname : Echelle
# uniques[0:3] : [u'Locale', u'R\x8egionale', u'D\x8epartementale']...
# u_count : 5
# - - - - -
# colname : Courriel
# uniques[0:3] : [u'mathias.bibliotheque@laposte.net', u'mediatheque.nogent.lartaud@wanadoo.fr', u'bibliocharly@orange.fr']...
# u_count : 454
# - - - - -
# colname : Telephone
# uniques[0:3] : [u'0323707844', u'0323706791', u'0323820032']...
# u_count : 576
# - - - - -
# colname : Accompagnement
# uniques[0:3] : [u'Oui', u'Possible', u'Acc\x8fs libre']...
# u_count : 45
# - - - - -
# colname : Conditions_acces
# uniques[0:3] : [u'Acc\x8fs libre', u'Acc\x8fs libre avec accompagnement personnalis\x8e sur demande', None]...
# u_count : 49
# - - - - -
# colname : Handicaps
# uniques[0:3] : [None, u'Oui', u'Non']...
# u_count : 23
# - - - - -
# colname : Horaires
# uniques[0:3] : [None, u'Du lundi au jeudi : 08:30-16:30 / Vendredi : 09:00-12:00', u'Du lundi au vendredi : 08:45-12:00']...
# u_count : 402
# - - - - -
# colname : Site_internet
# uniques[0:3] : [None, u'http://www.commune.de.chierry.com', u'https://www.pole-emploi.fr/accueil/']...
# u_count : 398
# - - - - -
# === === === === === === === === === ===
# columnsNames :
# Nom
# Présentation
# Photo
# Horaires d'ouverture
# Services itinérants
# Adresse
# Complément d'adresse
# Code Postal
# Ville
# Email de contact
# Site internet
# Téléphone
# Parking à proximité
# Accès transports en commun
# Plan d'accès
# Accessibilité
# Lien Facebook
# Lien Twitter
# Lien Google+
# Date de création de la fiche
# Date de la dernière modification de la fiche
# Pôle emploi
# CPAM
# CNAV
# GRDF
# La Poste
# MSA
# CAF
# Agence départementale d'information sur le logement (ADIL)
# Agence locale de lénergie (ALE)
# Banque de France
# Cap Emploi
# Centre communal d'action sociale (CCAS)
# Centre intercommunal daction sociale (CIAS)
# Centre local d'information et de coordination (CLIC)
# Centre social
# Chambre d'agriculture
# Chambre de commerce et d'industrie (CCI)
# Chambre de métiers et de l'artisanat (CMA)
# Conseil départemental
# Conseil départemental de laccès au droit (CDAD)
# Croix-Rouge
# Défenseur des droits
# EDF
# Fédération nationale des accidentés du travail et des handicapés (FNATH)
# Greta (formation continue pour les adultes)
# Maison de l'emploi
# Maison départementale des personnes handicapées (MDPH)
# Médecine du travail
# Mission locale
# Plan local pour l'insertion et lemploi (PLIE)
# Point d'accès au droit
# Point d'appui à la vie associative
# Point Info Famille
# Point Info Jeunesse
# Point Protection Maternelle Infantile
# Préfecture
# Protection, Amélioration, Conservation, Transformation de l'habitat (PACT)
# Régime social des indépendants (RSI)
# Réseau d'Ecoute, d'Appui et d'Accompagnement des Parents (REAAP)
# Trésor Public
# Union de Recouvrement des Cotisations de Sécurité Sociale et d'Allocations Familiales (URSSAF)
# Union départementale des associations familiales (UDAF)
# Autre
# Autres partenaires et services
# Planning des permanences
# Equipements à disposition
# Autres équipements
# Dans les mêmes locaux
# Autres services dans les locaux
# Année d'ouverture de la maison
# Année de labellisation de la maison
# Structure porteuse de la Maison de services au public
# Appartenance à un réseau territorial
# Connexion avec d'autres Maisons de services au public
# Autres labels
# Informations complémentaires
#
# colname : Nom
# uniques[0:3] : [u'Maison du Conseil d\xe9partemental de Cr\xe8vecoeur-le-Grand', u'Mercoeur', u'AACA']...
# u_count : 1276
# - - - - -
# colname : Présentation
# uniques[0:3] : [u"La Maison du Conseil d\xe9partemental de Cr\xe8vecoeur-le-Grand est \xe9galement Maison de Services Au Public. C 'est un service de proximit\xe9 , un lieu d '\xe9coute,d 'accompagnement et d'orientation dans lequel on trouve diverses permanences. Vous pouvez obtenir des informations sur les aides d\xe9partementales (Pass Permis Citoyen, Pass Sport, MDPH, APA, t\xe9l\xe9assistance, les services sociaux, la PMI...) Vous pouvez prendre des rendez-vous avec nos partenaires. Vous pouvez \xeatre accompagn\xe9 dans vos d\xe9marches administratives pour la constitution de vos dossiers, les services en ligne ( CAF, CPAM, MSA ,CARSAT, POLE EMPLOI, MISSION LOCALE, MEF, DGFIP PR\xc9FECTURE.... ) Un espace num\xe9rique est mis \xe0 votre disposition avec accompagnement si besoin.", u'LES MAISONS DE SERVICES AU PUBLIC DU D\xc9PARTEMENT DE LA CORR\xc8ZE : DES SERVICES PUBLICS AU PLUS PR\xc8S DE CHEZ VOUS. La MDDSAP de Mercoeur vous accueille les lundis, mercredis et vendredi pour vous accompagner dans toutes vos d\xe9marches administratives aupr\xe8s du Conseil D\xe9partemental mais \xe9galement aupr\xe8s de ses partenaires nationaux et locaux. Un agent vous accueille, vous informe et vous oriente avec un accompagnement personnalis\xe9 dans le montage de vos dossiers, une aide dans l\x92utilisation des services en ligne, une mise en relation avec des interlocuteurs sp\xe9cifiques.', u'L\x92AACA est un centre social, un lieu ressource, un lieu de convergence des habitants (familles, demandeurs d\x92emploi, jeunes, associations, b\xe9n\xe9voles, partenaires, \xe9lus\x85). Dans le cadre de La Maison de service au public c\x92est un espace essentiel au renforcement du lien social et des services \xe0 la population o\xf9 tous sont accueillis, \xe9cout\xe9s, renseign\xe9s, orient\xe9s et accompagn\xe9s dans leurs projets. Nous accordons une importance particuli\xe8re aux publics les plus fragiles. Depuis janvier 2016 nous sommes \xe9galement "Point relais CAF".']...
# u_count : 640
# - - - - -
# colname : Photo
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Horaires d'ouverture
# uniques[0:3] : [u'LUNDI : 14H-17H MARDI : 9H30-12H30 ET 14H-17H MERCREDI : 9H30-12H30 ET 14H-17H JEUDI : 9H30-12H30 ET 14H-17H VENDREDI : 9H30-12H30 ET 14H-17H', u'Lundi :\xa0 8h30 \xe0 12h30 et de 13h30 \xe0 17h30 Mercredi : 8h30 \xe0 12h30 et de 13h30 \xe0 17h30 Vendredi : 8h30 \xe0 12h30 et de 13h30 \xe0 17h30', u'Lundi de 10h \xe0 12h et de 14h \xe0 17h Mardi de 9h \xe0 12h Mercredi de 9h \xe0 12h et de 14h \xe0 17h Jeudi de 9h \xe0 12h et de 14h \xe0 17h Vendredi de 9h \xe0 12h']...
# u_count : 1232
# - - - - -
# colname : Services itinérants
# uniques[0:3] : [u'Non', u'Oui', None]...
# u_count : 3
# - - - - -
# colname : Adresse
# uniques[0:3] : [u'24 avenue du Ch\xe2teau', u'Le Bourg', u'All\xe9e du Ch\xe2teau']...
# u_count : 1210
# - - - - -
# colname : Complément d'adresse
# uniques[0:3] : [None, u'parc Rochette', u'Maison du Travail Saisonnier']...
# u_count : 166
# - - - - -
# colname : Code Postal
# uniques[0:3] : [60360, 19430, 73220]...
# u_count : 1235
# - - - - -
# colname : Ville
# uniques[0:3] : [u'Cr\xe8vec\x9cur-le-Grand', u'Merc\x9cur', u'Aiguebelle']...
# u_count : 1252
# - - - - -
# colname : Email de contact
# uniques[0:3] : [u'mcg-crevecoeur@oise.fr', u'maisondepartementmercoeur@correze.fr', u'al.chataux@aacaiguebelle.com']...
# u_count : 1213
# - - - - -
# colname : Site internet
# uniques[0:3] : [None, u'Site internet']...
# u_count : 2
# - - - - -
# colname : Téléphone
# uniques[0:3] : [u'0344108230', u'05.19.07.81.25', u'04 79 36 37 27 ']...
# u_count : 758
# - - - - -
# colname : Parking à proximité
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Accès transports en commun
# uniques[0:3] : [None, u'du lundi au vendredi 9H00/12H00\xa0 -\xa0 13H30/16H30 samedi 9H00/12H00', u'Aude Ligne Transport \xe0 la demande Transport scolaire']...
# u_count : 278
# - - - - -
# colname : Plan d'accès
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Accessibilité
# uniques[0:3] : [u'Handicap moteur', u'Handicap mental, Handicap moteur', u'Handicap auditif, Handicap mental, Handicap moteur, Handicap visuel']...
# u_count : 15
# - - - - -
# colname : Lien Facebook
# uniques[0:3] : [None, u'https://www.facebook.com/departementcorreze', u'https://www.facebook.com/MSAPAlboussiere/']...
# u_count : 163
# - - - - -
# colname : Lien Twitter
# uniques[0:3] : [None, u'https://twitter.com/MDSAlsaceBossue', u'https://twitter.com/MSAP_Cassel']...
# u_count : 25
# - - - - -
# colname : Lien Google+
# uniques[0:3] : [None, u'https://www.facebook.com/Maisons-de-services-au-public-Vosges-251491571576915/?r...', u'http://www.plateaudecaux.fr/vivre/social-sante/']...
# u_count : 17
# - - - - -
# colname : Date de création de la fiche
# uniques[0:3] : [u'12/10/2016', u'06/06/2017', u'24/02/2016']...
# u_count : 256
# - - - - -
# colname : Date de la dernière modification de la fiche
# uniques[0:3] : [u'17/04/2018', u'07/06/2018', u'19/06/2018']...
# u_count : 261
# - - - - -
# colname : Pôle emploi
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : CPAM
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : CNAV
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : GRDF
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : La Poste
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : MSA
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : CAF
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Agence départementale d'information sur le logement (ADIL)
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Agence locale de lénergie (ALE)
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Banque de France
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Cap Emploi
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Centre communal d'action sociale (CCAS)
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Centre intercommunal daction sociale (CIAS)
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Centre local d'information et de coordination (CLIC)
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Centre social
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Chambre d'agriculture
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Chambre de commerce et d'industrie (CCI)
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Chambre de métiers et de l'artisanat (CMA)
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Conseil départemental
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Conseil départemental de laccès au droit (CDAD)
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Croix-Rouge
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Défenseur des droits
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : EDF
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Fédération nationale des accidentés du travail et des handicapés (FNATH)
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Greta (formation continue pour les adultes)
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Maison de l'emploi
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Maison départementale des personnes handicapées (MDPH)
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Médecine du travail
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Mission locale
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Plan local pour l'insertion et lemploi (PLIE)
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Point d'accès au droit
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Point d'appui à la vie associative
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Point Info Famille
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Point Info Jeunesse
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Point Protection Maternelle Infantile
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Préfecture
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Protection, Amélioration, Conservation, Transformation de l'habitat (PACT)
# uniques[0:3] : [u'Non']...
# u_count : 1
# - - - - -
# colname : Régime social des indépendants (RSI)
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Réseau d'Ecoute, d'Appui et d'Accompagnement des Parents (REAAP)
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Trésor Public
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Union de Recouvrement des Cotisations de Sécurité Sociale et d'Allocations Familiales (URSSAF)
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Union départementale des associations familiales (UDAF)
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Autre
# uniques[0:3] : [u'Oui', u'Non']...
# u_count : 2
# - - - - -
# colname : Autres partenaires et services
# uniques[0:3] : [u"MEF(Maison Emploi Formation), APCE(Association Pour le Couple et l'Enfant), MDS(services sociaux du D\xe9partement)", u"Offre de services publics d\xe9partementaux : transport scolaire, APA, action sociale, bourses scolaires, petite enfance, num\xe9rique, financement participatif, boost emploi \x85 Autres partenaires : l'Instance de Coordination pour l'Autonomie des Xaintries, la Ligue pour la Protection des Oiseaux en Limousin et le CPIE de la Corr\xe8ze.", u"AIDER, ADAPT, AMIES Solid'Art"]...
# u_count : 562
# - - - - -
# colname : Planning des permanences
# uniques[0:3] : [u'Non', u'Oui']...
# u_count : 2
# - - - - -
# colname : Equipements à disposition
# uniques[0:3] : [u'Acc\xe8s Internet|Espace de confidentialit\xe9|Fax|Imprimante|Photocopieuse|Scanner|T\xe9l\xe9phone|Wifi', u'Acc\xe8s Internet|Fax|Imprimante|Photocopieuse|Scanner|T\xe9l\xe9phone', u'Acc\xe8s Internet|Espace de confidentialit\xe9|Fax|Imprimante|Photocopieuse|Scanner|T\xe9l\xe9phone']...
# u_count : 82
# - - - - -
# colname : Autres équipements
# uniques[0:3] : [u'SALLE DE R\xc9UNION', u'Salle de r\xe9union - Biblioth\xe8que', None]...
# u_count : 134
# - - - - -
# colname : Dans les mêmes locaux
# uniques[0:3] : [u'Espace Public Num\xe9rique|Relai Assistantes Maternelles (RAM)', u'Biblioth\xe8que', u'Centre social|Relai Assistantes Maternelles (RAM)']...
# u_count : 203
# - - - - -
# colname : Autres services dans les locaux
# uniques[0:3] : [None, u"Service d'animation du centre social (Education pour l'environnement et Vie Sociale) : \xe9coles et grand public Service d'aide \xe0 domicile Antenne SSIAD - Service de Soins Infirmiers \xe0 Domicile Initiation/Formation individuelle \xe0 la demande : bases de l'informatique, internet et t\xe9l\xe9phonie.", u'agence postale communale']...
# u_count : 270
# - - - - -
# colname : Année d'ouverture de la maison
# uniques[0:3] : [u'05/07/2008', u'27/04/2007', None]...
# u_count : 542
# - - - - -
# colname : Année de labellisation de la maison
# uniques[0:3] : [u'05/07/2008', u'18/04/2017', u'01/06/2011']...
# u_count : 458
# - - - - -
# colname : Structure porteuse de la Maison de services au public
# uniques[0:3] : [u'DEPARTEMENT OISE', u'D\xe9partement de la Corr\xe8ze', u"AACA : Association d'Animation du Canton d'Aiguebelle"]...
# u_count : 595
# - - - - -
# colname : Appartenance à un réseau territorial
# uniques[0:3] : [None, u'ADRETS', u'R\xe9seau D\xe9partemental des maisons de Services au Public de l\'Aude. F\xe9d\xe9ration Nationale et R\xe9gionale des Centres Sociaux. R\xe9seau GEEAUDE (Groupe d\'Education pour l\'Environnement de l\'Aude). R\xe9seau d\'\xe9ducation pour l\'environnement "Pour des Pyr\xe9n\xe9es Vivantes".']...
# u_count : 120
# - - - - -
# colname : Connexion avec d'autres Maisons de services au public
# uniques[0:3] : [None, u'Beaulieu, Beynat, Eygurande, Saint Privat, Sornac', u"POM'S de LAROQUE DE FA, POM'S de DAVEJEAN, POM's de BOUISSE, POM'S de FELINES-TERMENES, POM'S de LANET, POM'S de MOUTHOUMET, POM'S de SOULATGE, POM'S de VIGNEVIEILLE, POM'S de VILLEROUGE-TERMENES"]...
# u_count : 137
# - - - - -
# colname : Autres labels
# uniques[0:3] : [u'MAISON DU CONSEIL DEPARTEMENTAL', None, u'Point relais CAF']...
# u_count : 128
# - - - - -
# colname : Informations complémentaires
# uniques[0:3] : [None, u"SERVICE PUBLIC GRATUIT ET SANS RDV A LA MSAP La Maison de Services Au Public des Vall\xe9es de la Haute-Meurthe a \xe9t\xe9, \xe0 l'origine, labellis\xe9e Relais de Services Publics en 2012.", u'La MSAP fait suite au Relais Services Publics ouvert en janvier 2012']...
# u_count : 48
# - - - - -
# === === === === === === === === === ===
# columnsNames :
# Nom du lieu
# Nom du porteur
# Adresse mail
# Type de porteur
# Détail du type de porteur
# Adresse
# Code postal
# Commune
# Code INSEE
# Numéro de téléphone
# Site web
# Descriptif
# Logo
# Photo
# Public
# Accès
# Restrictions d'usage
# Tarif(s)
# Horaires du lundi
# Horaires du mardi
# Horaires du mercredi
# Horaires du jeudi
# Horaires du vendredi
# Horaires du samedi
# Horaires du dimanche
# Complément sur les horaires
# Ordinateur(s)
# Tablette(s)
# Scanner(s)
# Imprimante(s)
# Borne(s) CAF
# Connexion Wi-Fi
# Complément sur les équipements
# Formation
# Accompagnement individuel
# Fourniture d'équipement
# Complément sur les services
# Compte InfoLocale
# Localisation
# Clé
# Date de saisie
# Date d'enregistrement
# Date de modification
# Services
# Équipements
# Ordinateur(s) libellé
# Tablette(s) libellé
# Scanner(s) libellé
# Imprimante(s) libellé
# Borne(s) CAF libellé
# Connexion Wi-Fi libellé
# Formation libellé
# Accompagnement individuel individuel libellé
# Fourniture d'équipement libellé
#
# colname : Nom du lieu
# uniques[0:3] : [u'Biblioth\xe8que A Livre Ouvert', u'CCAS Le Croisic', u"Caisse d'Allocations Familiales Clisson"]...
# u_count : 207
# - - - - -
# colname : Nom du porteur
# uniques[0:3] : [u'Biblioth\xe8que A Livre Ouvert', u'CCAS Le Croisic', u"Caisse d'Allocations Familiales"]...
# u_count : 192
# - - - - -
# colname : Adresse mail
# uniques[0:3] : [u'bibliotheque@sainte-pazanne.com', u'ccas@lecroisic.fr', None]...
# u_count : 144
# - - - - -
# colname : Type de porteur
# uniques[0:3] : [u'Biblioth\xe8que / M\xe9diath\xe8que', u'Institution', u'Association']...
# u_count : 4
# - - - - -
# colname : Détail du type de porteur
# uniques[0:3] : [None, u'B\xe9n\xe9vole', u'Secteur priv\xe9']...
# u_count : 4
# - - - - -
# colname : Adresse
# uniques[0:3] : [u'32 avenue de la source', u'3 rue de la Duchesse Anne', u'2 rue du Docteur Doussain']...
# u_count : 208
# - - - - -
# colname : Code postal
# uniques[0:3] : [44680, 44490, 44190]...
# u_count : 59
# - - - - -
# colname : Commune
# uniques[0:3] : [u'Sainte-Pazanne', u'Le Croisic', u'Clisson']...
# u_count : 114
# - - - - -
# colname : Code INSEE
# uniques[0:3] : [44186, 44049, 44043]...
# u_count : 115
# - - - - -
# colname : Numéro de téléphone
# uniques[0:3] : [u'0240026913', u'0228567900', u'0240540212']...
# u_count : 202
# - - - - -
# colname : Site web
# uniques[0:3] : [u'http://www.bibliotheque-sainte-pazanne.net/', u'https://www.loire-atlantique.fr/jcms/classement-des-contenus/lieux/par-types-de-lieu/service/centres-communaux-d-action-sociale-ccas/centre-communal-d-action-sociale-ccas-du-croisic-fr-t1_36195', u'http://www.caf.fr/allocataires/caf-de-loire-atlantique/actualites']...
# u_count : 167
# - - - - -
# colname : Descriptif
# uniques[0:3] : [None, u"Centre communal d'action sociale du Croisic.", u'Relais CAF de Clisson']...
# u_count : 81
# - - - - -
# colname : Logo
# uniques[0:3] : [None, u'index.png', u'ecvn_logo_ecn_vert.jpg']...
# u_count : 12
# - - - - -
# colname : Photo
# uniques[0:3] : [None, u'batiment-vue-rapprochee_medium.jpg', u'photoloireauxence.jpg']...
# u_count : 3
# - - - - -
# colname : Public
# uniques[0:3] : [u'tout public', u'11-17 ans', u'travailleurs ind\xe9pendants']...
# u_count : 13
# - - - - -
# colname : Accès
# uniques[0:3] : [None, u"Lila ligne 6 vers Le cimeti\xe8re (Le Croisic), arr\xeat L'aiguillon (Le Croisic).", u'proche gare de Clisson']...
# u_count : 53
# - - - - -
# colname : Restrictions d'usage
# uniques[0:3] : [None, u'uniquement adh\xe9rents', u"uniquement pour les recherches d'emploi"]...
# u_count : 30
# - - - - -
# colname : Tarif(s)
# uniques[0:3] : [u"gratuit : \xe9tudiants et demandeurs d'emploi \u25aa Consultations r\xe9guli\xe8res + acc\xe8s wifi : adh\xe9sion 8\u20ac/an \u25aa Ateliers : 5\u20ac/atelier ou 30\u20ac le forfait annuel (CC Coeur  Pays de Retz) - 10\u20ac/atelier (hors CC Coeur Pays de Retz)", u'gratuit', u'gratuit ou prix tr\xe8s r\xe9duit']...
# u_count : 57
# - - - - -
# colname : Horaires du lundi
# uniques[0:3] : [u'ferm\xe9', u'8h30-12h 13h15-17h30', u'9h-12h15 14h-17h15']...
# u_count : 62
# - - - - -
# colname : Horaires du mardi
# uniques[0:3] : [u'ferm\xe9', u'8h30-12h 13h15-17h30', u'9h-12h15 14h-17h15']...
# u_count : 100
# - - - - -
# colname : Horaires du mercredi
# uniques[0:3] : [u'10h-12h30 14h-18h30', u'8h30-12h 13h15-17h30', u'9h-12h15 14h-17h15']...
# u_count : 135
# - - - - -
# colname : Horaires du jeudi
# uniques[0:3] : [u'ferm\xe9', u'8h30-12h 13h15-17h30', u'9h-12h15']...
# u_count : 83
# - - - - -
# colname : Horaires du vendredi
# uniques[0:3] : [u'10h-12h30 16h-19h', u'8h30-12h 13h15-16h', u'9h-12h15 14h-17h15']...
# u_count : 103
# - - - - -
# colname : Horaires du samedi
# uniques[0:3] : [u'10h-15h', u'ferm\xe9', u'9h-12h']...
# u_count : 78
# - - - - -
# colname : Horaires du dimanche
# uniques[0:3] : [u'ferm\xe9', None, u'10h-12h']...
# u_count : 18
# - - - - -
# colname : Complément sur les horaires
# uniques[0:3] : [None, u'Accueil ouvert de 14h \xe0 19h pendant les vacances scolaires du lundi au vendredi.', u'Pendant les vacances scolaires ouverture \xe0 14h30 le mardi et le vendredi au lieu de 16h.']...
# u_count : 65
# - - - - -
# colname : Ordinateur(s)
# uniques[0:3] : [1, 0]...
# u_count : 2
# - - - - -
# colname : Tablette(s)
# uniques[0:3] : [0, 1]...
# u_count : 2
# - - - - -
# colname : Scanner(s)
# uniques[0:3] : [0, 1]...
# u_count : 2
# - - - - -
# colname : Imprimante(s)
# uniques[0:3] : [1, 0]...
# u_count : 2
# - - - - -
# colname : Borne(s) CAF
# uniques[0:3] : [0, 1]...
# u_count : 2
# - - - - -
# colname : Connexion Wi-Fi
# uniques[0:3] : [1, 0]...
# u_count : 2
# - - - - -
# colname : Complément sur les équipements
# uniques[0:3] : [u'5 ordinateurs + 1 pour le catalogue', None, u"Agents d'accueils sur les horaires d'ouverture"]...
# u_count : 97
# - - - - -
# colname : Formation
# uniques[0:3] : [1, 0]...
# u_count : 2
# - - - - -
# colname : Accompagnement individuel
# uniques[0:3] : [1, 0]...
# u_count : 2
# - - - - -
# colname : Fourniture d'équipement
# uniques[0:3] : [0, 1]...
# u_count : 2
# - - - - -
# colname : Complément sur les services
# uniques[0:3] : [u"Cours d'initiation informatique : 1 animatrice uniquement le mardi de 10h \xe0 12h", None, u'Cr\xe9ation de compte CAF et versement des prestations sociales.']...
# u_count : 69
# - - - - -
# colname : Compte InfoLocale
# uniques[0:3] : [None, u"A partir du 21 mars, vente en plein air : v\xe9los, campings, mobilier, jeux \xe0 l'EcoCyclerie de Vallet", u'https://infolocale.ouest-france.fr/clisson-44043/annuaire/gullivigne_366516']...
# u_count : 6
# - - - - -
# colname : Localisation
# uniques[0:3] : [u'47.102786, -1.803742', u'47.294264, -2.513761', u'47.092043, -1.290544']...
# u_count : 206
# - - - - -
# colname : Clé
# uniques[0:3] : [u'LX58-W3DV', u'ASJN-HKGY', u'4B7E-L9D5']...
# u_count : 219
# - - - - -
# colname : Date de saisie
# uniques[0:3] : [u'2019-10-01T14:04:14+02:00', u'2019-11-02T15:25:13+01:00', u'2018-11-14T17:39:44+01:00']...
# u_count : 210
# - - - - -
# colname : Date d'enregistrement
# uniques[0:3] : [u'2019-10-01T14:04:14+02:00', u'2019-11-02T15:25:13+01:00', u'2018-11-14T17:39:44+01:00']...
# u_count : 210
# - - - - -
# colname : Date de modification
# uniques[0:3] : [u'2019-11-02T15:23:12+01:00', u'2019-11-02T15:25:20+01:00', u'2019-11-02T15:24:28+01:00']...
# u_count : 178
# - - - - -
# colname : Services
# uniques[0:3] : [u'Formation,Accompagnement individuel', u'Accompagnement individuel', None]...
# u_count : 8
# - - - - -
# colname : Équipements
# uniques[0:3] : [u'Ordinateur(s),Imprimante(s),Connexion Wi-Fi', u'Borne(s) CAF', u'Ordinateur(s),Imprimante(s)']...
# u_count : 27
# - - - - -
# colname : Ordinateur(s) libellé
# uniques[0:3] : [u'Ordinateur(s)', None]...
# u_count : 2
# - - - - -
# colname : Tablette(s) libellé
# uniques[0:3] : [None, u'Tablette(s)']...
# u_count : 2
# - - - - -
# colname : Scanner(s) libellé
# uniques[0:3] : [None, u'Scanner(s)']...
# u_count : 2
# - - - - -
# colname : Imprimante(s) libellé
# uniques[0:3] : [u'Imprimante(s)', None]...
# u_count : 2
# - - - - -
# colname : Borne(s) CAF libellé
# uniques[0:3] : [None, u'Borne(s) CAF']...
# u_count : 2
# - - - - -
# colname : Connexion Wi-Fi libellé
# uniques[0:3] : [u'Connexion Wi-Fi', None]...
# u_count : 2
# - - - - -
# colname : Formation libellé
# uniques[0:3] : [u'Formation', None]...
# u_count : 2
# - - - - -
# colname : Accompagnement individuel individuel libellé
# uniques[0:3] : [u'Accompagnement individuel', None]...
# u_count : 2
# - - - - -
# colname : Fourniture d'équipement libellé
# uniques[0:3] : [None, u"Fourniture d'\xe9quipement"]...
# u_count : 2
# - - - - -
# === === === === === === === === === ===
# columnsNames :
# Identifiant
# Date de dernière modification
# Nom
# Label
# Label Net-Public
# Demande de labellisation Net-Public
# Site Web
# N° et libellé de voie
# Code Insee commune
# Code postal
# Localité
# Téléphone
# Email
# Latitude
# Longitude
# Précision
# Personne à contacter
# Services proposés
# Nombre d'animateurs
# Numéro DUI
# Photo
# Statut
# Autre label
# N° et libellé de voie.1
# Horaires d'ouverture
# Entrée - Accès [Accessibilité]
# Équipement
# Entrée - Ouverture de porte [Accessibilité]
# Entrée - Obstacle à la porte d'entrée [Accessibilité]
# Circulation - Circulation dans les allées [Accessibilité]
# Circulation - Accès en fauteuil dans tout le lieu [Accessibilité]
# Circulation - Ascenseurs (dimensions) [Accessibilité]
# Services et équipements - Sanitaires [Accessibilité]
# Services et équipements - Personnel formé à l'accueil des personnes en situation de handicap [Accessibilité]
# Services et équipements - Personnel initié à la langue des signes [Accessibilité]
# Extérieur - Place de parking réservée [Accessibilité]
# Extérieur - Places GIC/GIR à proximité [Accessibilité]
# Extérieur - Transports accessibles à proximité [Accessibilité]
# Tarif
# Photo.1
# Photo.2
# Photo.3
# N° et libellé de voie.2
# Code Insee commune.1
# Code postal.1
# Localité.1
# N° et libellé de voie.3
# Circulation - Signalétique adaptée [Accessibilité]
# Services et équipements - Hauteur adaptée des comptoirs / guichets [Accessibilité]
# services et équipements - Personnel formé à l'accueil des personnes en situation de handicap [Accessibilité]
# Services et équipements - Place réservée au PMR [Accessibilité]
# Extérieur - Enseigne suffisamment lisible et visible [Accessibilité]
# Spécificité territoriale
# Circulation - Ascenseurs (adaptations) [Accessibilité]
# Photo.4
# Photo.5
# Photo.6
# Photo.7
# Photo.8
# Flux d'actualité
# Courriel
# Horaires initiations et ateliers
# Entrée - Accès contrôlé [Accessibilité]
# Circulation - Escaliers [Accessibilité]
# Services et équipements - Visites adaptées aux personnes ayant une déficience [Accessibilité]
# Entrée - Largeur de porte en cm [Accessibilité]
# Circulation - Guidage [Accessibilité]
# Blog
# Extérieur - Trottoirs (Obstacles) [Accessibilité]
# Entrée - En cas de présence d'une marche, préciser sa hauteur en cm [Accessibilité]
# Rue, Voie, Chemin
# Rue, Voie, Chemin.1
# Fédération Nationale de Sport Numérique
# Ateliers
# Espace Public Numérique (EPN des Yvelines)
# Commentaire
# Intitulé
# Autre Site Web
# Texte long
# N° et libellé de voie.4
# N° et libellé de voie.5
# Code Insee commune.2
# Code postal.2
# Localité.2
# Site Web2
# Vidéo
# Circulation - Plan du lieu [Accessibilité]
# NETPUBLIC
# Site Web de Formation ORDIDACTIC60
# Vidéo.1
# Visio-accueil Pôle-Emploi
# Le blog de la médiathèque
# Fax
# Ce flux présente les actualités locales de l'Espace Informatique Cyber-base®
# Ce flux affiche les programmes des ateliers qui sont planifiés à l'Espace Informatique Cyber-base®
# Services proposés.1
# Villes Internet
# Accueil de jeunes
# Accueil de seniors
# Organisation d'évènements
# Centre d'Animation des Portes Ferrées
# Personne à contacter.1
# Image
# N° et libellé de voie.6
# Mission
#
# colname : Identifiant
# uniques[0:3] : [None, u'4f3401aade77fe55ff00063c', u'4B']...
# u_count : 336
# - - - - -
# colname : Date de dernière modification
# uniques[0:3] : [None, u'14/02/2012', u'18/03/2013']...
# u_count : 10
# - - - - -
# colname : Nom
# uniques[0:3] : [u'Centre Socio culturel la Passerelle', u'M\xe9diath\xe8que Fran\xe7ois Mitterrand', u'BIJ']...
# u_count : 209
# - - - - -
# colname : Label
# uniques[0:3] : [u'PAPI', u'Cyber-base', None]...
# u_count : 11
# - - - - -
# colname : Label Net-Public
# uniques[0:3] : [None, u'1', u'Jeunesse']...
# u_count : 10
# - - - - -
# colname : Demande de labellisation Net-Public
# uniques[0:3] : [None, 0.0, 1.0]...
# u_count : 3
# - - - - -
# colname : Site Web
# uniques[0:3] : [None, u'www.mairie-ambes.fr', u'http://en cours/']...
# u_count : 131
# - - - - -
# colname : N° et libellé de voie
# uniques[0:3] : [u'2 Place du Mar\xe9chal Leclerc', u'5 avenue du docteur Couaillac', u'Centre Georges Brassens Place du 11 Novembre']...
# u_count : 286
# - - - - -
# colname : Code Insee commune
# uniques[0:3] : [None, 33004.0, 4.0]...
# u_count : 206
# - - - - -
# colname : Code postal
# uniques[0:3] : [33440.0, 33810.0, 33510.0]...
# u_count : 86
# - - - - -
# colname : Localité
# uniques[0:3] : [u'Ambar\xe8s-et-Lagrave', u'AMBES', u'Amb\xe8s']...
# u_count : 206
# - - - - -
# colname : Téléphone
# uniques[0:3] : [u'05 56 77 62 64', u'+33 5 56 77 02 69', u'05 56 77 30 56']...
# u_count : 304
# - - - - -
# colname : Email
# uniques[0:3] : [u'csclapasserelle@free.fr', u'biblio@mairie-ambes.fr', None]...
# u_count : 259
# - - - - -
# colname : Latitude
# uniques[0:3] : [None, u'45.01154', u'brassens26@hotmail.com']...
# u_count : 155
# - - - - -
# colname : Longitude
# uniques[0:3] : [None, -0.532559, -1.086503]...
# u_count : 144
# - - - - -
# colname : Précision
# uniques[0:3] : [None, 8.0, 4.0]...
# u_count : 6
# - - - - -
# colname : Personne à contacter
# uniques[0:3] : [None, u'Pierre Ch\xe9nier', u'Jeannine FONCK\nPr\xe9sidente Association E.S.P.O.I.R.\n9, avenue J. Moulin \n33510 ANDERNOS LES BAINS']...
# u_count : 163
# - - - - -
# colname : Services proposés
# uniques[0:3] : [None, u"Accompagnement individuel\nInitiation Internet et multim\xe9dia\nPratiques culturelles, cr\xe9ation artistique \nAccompagnement scolaire, activit\xe9s \xe9ducatives\nRecherche d'emploi sur Internet\nD\xe9marches administratives", u"Accompagnement individuel\nInitiation Internet et multim\xe9dia\nPerfectionnement, accompagnement de projets\nPratiques culturelles, cr\xe9ation artistique \nAccompagnement scolaire, activit\xe9s \xe9ducatives\nRecherche d'emploi sur Internet\nD\xe9marches administratives"]...
# u_count : 28
# - - - - -
# colname : Nombre d'animateurs
# uniques[0:3] : [None, u'1', u'3']...
# u_count : 7
# - - - - -
# colname : Numéro DUI
# uniques[0:3] : [None, 10108.0, 10537.0]...
# u_count : 157
# - - - - -
# colname : Photo
# uniques[0:3] : [None, u'<p>\n\t<img alt="Plan d\'acc\xc3\u0161s" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/571592.png" /></p>\n<p>\n\t<img alt="Salle Principale" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/9500473.jpg" style="height: 400px; " /></p>', u'<image alt="Cyber-base Le Haillan" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/7542371.jpg" />']...
# u_count : 6
# - - - - -
# colname : Statut
# uniques[0:3] : [None, u'Structure associative', u'Collectivit\xe9 publique']...
# u_count : 3
# - - - - -
# colname : Autre label
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : N° et libellé de voie.1
# uniques[0:3] : [None, u'Maison des Associations']...
# u_count : 2
# - - - - -
# colname : Horaires d'ouverture
# uniques[0:3] : [None, u'Mardi/Vendredi : 9h-12h/14h-19h Samedi : 14h-19h ', u'Lundi au vendredi : 9h-12H/13h30-17H']...
# u_count : 99
# - - - - -
# colname : Entrée - Accès [Accessibilité]
# uniques[0:3] : [None, u'Rampe', u'Plain-pied']...
# u_count : 3
# - - - - -
# colname : Équipement
# uniques[0:3] : [None, u'6 postes pour la formation\n2 postes en acc\xe8s libre', u'- 6 ordinateurs MAC OS X & Windows XP\n- 1 ordinateur Windows VISTA, Windows 7 & UBUNTU\n- Imprimante laser couleur/Scanner']...
# u_count : 8
# - - - - -
# colname : Entrée - Ouverture de porte [Accessibilité]
# uniques[0:3] : [None, u'Manuelle']...
# u_count : 2
# - - - - -
# colname : Entrée - Obstacle à la porte d'entrée [Accessibilité]
# uniques[0:3] : [None, u"Absence de marquage sur la porte d'entr\xe9e\nPorte difficile \xe0 maintenir ouverte\nPoign\xe9e peu ergonomique"]...
# u_count : 2
# - - - - -
# colname : Circulation - Circulation dans les allées [Accessibilité]
# uniques[0:3] : [None, u'Ais\xe9e']...
# u_count : 2
# - - - - -
# colname : Circulation - Accès en fauteuil dans tout le lieu [Accessibilité]
# uniques[0:3] : [None, u'Total']...
# u_count : 2
# - - - - -
# colname : Circulation - Ascenseurs (dimensions) [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Services et équipements - Sanitaires [Accessibilité]
# uniques[0:3] : [None, u'Am\xe9nag\xe9s']...
# u_count : 2
# - - - - -
# colname : Services et équipements - Personnel formé à l'accueil des personnes en situation de handicap [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Services et équipements - Personnel initié à la langue des signes [Accessibilité]
# uniques[0:3] : [None, 0.0]...
# u_count : 2
# - - - - -
# colname : Extérieur - Place de parking réservée [Accessibilité]
# uniques[0:3] : [None, 1.0]...
# u_count : 2
# - - - - -
# colname : Extérieur - Places GIC/GIR à proximité [Accessibilité]
# uniques[0:3] : [None, 1.0]...
# u_count : 2
# - - - - -
# colname : Extérieur - Transports accessibles à proximité [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Tarif
# uniques[0:3] : [None, u'Gratuit', u'Payant']...
# u_count : 9
# - - - - -
# colname : Photo.1
# uniques[0:3] : [None, u'<image alt="Nos cours quotidiens" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/7557363.jpg" />', u'<image alt="Atelier pr\xc3\xa9sentation Ubuntu" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/8120966.jpg" />']...
# u_count : 3
# - - - - -
# colname : Photo.2
# uniques[0:3] : [None, u'<image alt="10 postes - 3 plateformes" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/5747468.jpg" />']...
# u_count : 2
# - - - - -
# colname : Photo.3
# uniques[0:3] : [None, u'<image alt="Vid\xc3\xa9o-projection sur grand \xc3\xa9cran" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/8956865.jpg" />']...
# u_count : 2
# - - - - -
# colname : N° et libellé de voie.2
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Code Insee commune.1
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Code postal.1
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Localité.1
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : N° et libellé de voie.3
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Circulation - Signalétique adaptée [Accessibilité]
# uniques[0:3] : [None, 1.0]...
# u_count : 2
# - - - - -
# colname : Services et équipements - Hauteur adaptée des comptoirs / guichets [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : services et équipements - Personnel formé à l'accueil des personnes en situation de handicap [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Services et équipements - Place réservée au PMR [Accessibilité]
# uniques[0:3] : [None, 0.0]...
# u_count : 2
# - - - - -
# colname : Extérieur - Enseigne suffisamment lisible et visible [Accessibilité]
# uniques[0:3] : [None, 1.0]...
# u_count : 2
# - - - - -
# colname : Spécificité territoriale
# uniques[0:3] : [None, u'ZRR (zone de revitalisation rurale)']...
# u_count : 2
# - - - - -
# colname : Circulation - Ascenseurs (adaptations) [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Photo.4
# uniques[0:3] : [None, u'<image alt="Samedis du Libre - Ateliers" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/9652688.jpg" />']...
# u_count : 2
# - - - - -
# colname : Photo.5
# uniques[0:3] : [None, u'<image alt="Accueil Soutien des demandeurs d&#39;emploi" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/4846713.jpg" />']...
# u_count : 2
# - - - - -
# colname : Photo.6
# uniques[0:3] : [None, u'<image alt="Poste Macinstosh" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/8041483.jpg" />']...
# u_count : 2
# - - - - -
# colname : Photo.7
# uniques[0:3] : [None, u'<image alt="Poste Linux/Ubuntu" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/6660632.jpg" />']...
# u_count : 2
# - - - - -
# colname : Photo.8
# uniques[0:3] : [None, u'<image alt="8 postes en double boot : Windows 7/Ubuntu" height="400" src="http://delegation.internet.gouv.fr/bddui/api/images/photos_epn/448371.jpg" />']...
# u_count : 2
# - - - - -
# colname : Flux d'actualité
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Courriel
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Horaires initiations et ateliers
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Entrée - Accès contrôlé [Accessibilité]
# uniques[0:3] : [None, u"Visiteur visible depuis l'int\xe9rieur"]...
# u_count : 2
# - - - - -
# colname : Circulation - Escaliers [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Services et équipements - Visites adaptées aux personnes ayant une déficience [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Entrée - Largeur de porte en cm [Accessibilité]
# uniques[0:3] : [None, u'92 cm']...
# u_count : 2
# - - - - -
# colname : Circulation - Guidage [Accessibilité]
# uniques[0:3] : [None, u'Visuel']...
# u_count : 2
# - - - - -
# colname : Blog
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Extérieur - Trottoirs (Obstacles) [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Entrée - En cas de présence d'une marche, préciser sa hauteur en cm [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Rue, Voie, Chemin
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Rue, Voie, Chemin.1
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Fédération Nationale de Sport Numérique
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Ateliers
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Espace Public Numérique (EPN des Yvelines)
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Commentaire
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Intitulé
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Autre Site Web
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Texte long
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : N° et libellé de voie.4
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : N° et libellé de voie.5
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Code Insee commune.2
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Code postal.2
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Localité.2
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Site Web2
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Vidéo
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Circulation - Plan du lieu [Accessibilité]
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : NETPUBLIC
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Site Web de Formation ORDIDACTIC60
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Vidéo.1
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Visio-accueil Pôle-Emploi
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Le blog de la médiathèque
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Fax
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Ce flux présente les actualités locales de l'Espace Informatique Cyber-base®
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Ce flux affiche les programmes des ateliers qui sont planifiés à l'Espace Informatique Cyber-base®
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Services proposés.1
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Villes Internet
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Accueil de jeunes
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Accueil de seniors
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Organisation d'évènements
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Centre d'Animation des Portes Ferrées
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Personne à contacter.1
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Image
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : N° et libellé de voie.6
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# colname : Mission
# uniques[0:3] : [None]...
# u_count : 1
# - - - - -
# === === === === === === === === === ===

# %%
CSV_dfList[0]["df"].head(3)
# Out:
#     Id          Enjeu                                         Dispositif  \
# 0  617  Accessibilit  Mise  disposition de matriel informatique et...
# 1  616  Accessibilit  Mise  disposition de matriel informatique et...
# 2  590  Accessibilit  Mise  disposition de matriel informatique et...
#
#   Public_cible                              Descriptif  \
# 0  Tout public  Accs  Internet dans la bibliothque.
# 1  Tout public  Accs  Internet dans la bibliothque.
# 2  Tout public  Accs  Internet dans la bibliothque.
#
#          Structure_porteuse              Type_structure  Statut  \
# 0       Bibliotheque Rurale  Bibliothque - Mdiathque  Public
# 1  Mediatheque Henry Murger  Bibliothque - Mdiathque  Public
# 2   Bibliotheque Municipale  Bibliothque - Mdiathque  Public
#
#                            Adresse           Commune      ...         Dpt  \
# 0       PLACE DU GENERAL DE GAULLE            Pavant      ...       Aisne
# 1               PARC DU 8 MAI 1945   Nogent-l'Artaud      ...       Aisne
# 2  Centre culturel Ferdinand Pinal  Charly-sur-Marne      ...       Aisne
#
#             Region Echelle                               Courriel   Telephone  \
# 0  Hauts-de-France  Locale       mathias.bibliotheque@laposte.net  0323707844
# 1  Hauts-de-France  Locale  mediatheque.nogent.lartaud@wanadoo.fr  0323706791
# 2  Hauts-de-France  Locale                 bibliocharly@orange.fr  0323820032
#
#   Accompagnement Conditions_acces Handicaps Horaires Site_internet
# 0            Oui      Accs libre      None     None          None
# 1            Oui      Accs libre      None     None          None
# 2            Oui      Accs libre      None     None          None
#
# [3 rows x 21 columns]

# %%
for csvClass in CSV_dfList:
    csvClass["classCSV"].toXLS()
    csvClass["classCSV"].toTSV()
